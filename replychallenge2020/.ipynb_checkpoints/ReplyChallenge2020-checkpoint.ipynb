# %%
import numpy as np
from operator import attrgetter

# %%
filenames = ['data/a_solar.txt', 
             'data/b_dream.txt',
             'data/c_soup.txt',
             'data/d_maelstrom.txt',
             'data/e_igloos.txt', 
             'data/f_glitch.txt']

l = 'b'

int_to_letter = {0 : 'a', 1 : 'b', 2 : 'c', 3 : 'd', 4 : 'f', 5 : 'g'}
letter_to_int = {'a':0, 'b':1, 'c':2, 'd':3, 'e':4, 'f':5}

f = open(filenames[letter_to_int[l]])

# %%
class Person():
    def __init__(self, index, company, bonus):
        self.index = index
        self.company = company
        self.bonus = bonus
        self.placed = 0
        self.coord = []
        
    def getScoreWith(self, otherPerson):
        if (otherPerson != None and self.company == otherPerson.company) :
            return self.bonus * otherPerson.bonus
        return 0

class Developer(Person):
    
    def __init__(self, index, company, bonus, skills):
        super(Developer, self).__init__(index, company, bonus)
        self.skills = skills
        self.numSkills = len(skills)
    
    def getScoreWith(self, otherPerson):
        bonus = super().getScoreWith(otherPerson)
        if (otherPerson != None and isinstance(otherPerson, Developer)):
            numCommonSkills = len(set(self.skills).intersection(otherPerson.skills))
            numDifferentSkills = len(self.skills) + len(otherPerson.skills) - 2*numCommonSkills
            return bonus + (numCommonSkills*numDifferentSkills)
        return bonus
        
class ProjectManager(Person):
     def __init__(self, index, company, bonus):
        super(ProjectManager, self).__init__(index, company, bonus)

def convertCharForMap(char):
    if (char == '#'):
        return 0
    elif (char == '_'):
        return 1
    else:
        return 2
    
def getBestForArg(listToChoseIn, other = None):
    bestPer = None
    if other != None:
        max_score = 0
        for per in listToChoseIn:
            if per.placed == 0:
                score = per.getScoreWith(other)
                if score > max_score:
                    max_score = score
                    bestPer = per
    return bestPer, max_score
     
def getBest(listToChoseIn, upperNei = None, leftNei = None):
    bestPer = None
    if upperNei != None or leftNei != None:
        max_score = 0
        for per in listToChoseIn:
            if per.placed == 0:
                score = per.getScoreWith(upperNei)
                score += per.getScoreWith(leftNei)
                if score > max_score:
                    max_score = score
                    bestPer = per
        if bestPer != None:
            bestPer.placed = 1
    return bestPer

def getBestDev(list_of_dev, upperNei = None, leftNei = None):
    choosen = getBest(list_of_dev, upperNei, leftNei)
    if choosen == None:
        choosen = max(list_of_dev, key=attrgetter('numSkills'))
        choosen.placed = 1
    list_of_dev.remove(choosen)
    return choosen

def getBestMan(list_of_managers, upperNei = None, leftNei = None):
    choosen = getBest(list_of_managers, upperNei, leftNei)
    if choosen == None:
        choosen = max(list_of_managers, key=attrgetter('bonus'))
        choosen.placed = 1
    list_of_managers.remove(choosen)
    return choosen

# %%
#Parse input file
print('Reading first line')
line = f.readline()
W = int(line.split(' ')[0])
H = int(line.split(' ')[1])
# Out:
# Reading first line

# %%
office_map = np.zeros((H,W))

# %%
for h in range(H):
    line = f.readline()
    for w in range(W):
        office_map[h,w] = convertCharForMap(line[w])

# %%
#print(office_map)

# %%
line = f.readline()
D = int(line)
developers = []

# %%
# Developers
for d in range(D):
    line = f.readline()
    lineSplit = line.split(' ')
    company = lineSplit[0]
    bonus = int(lineSplit[1])
    numSkills = int(lineSplit[2])
    skills = []
    for i in range(3, numSkills + 3):
        skills.append(lineSplit[i])
    developers.append(Developer(d, company, bonus, skills))

# %%
# Managers
line = f.readline()
M = int(line)
managers = []
for m in range(M):
    line = f.readline()
    lineSplit = line.split(' ')
    company = lineSplit[0]
    bonus = int(lineSplit[1])
    managers.append(ProjectManager(m, company, bonus))

# %%
out_map = []
devsLeft = developers.copy()
mansLeft = managers.copy()
score = 0
for r in range(H):
    if (r%10 == 0):
        print(r)
    out_map.append([])
    for c in range(W):
        upperNei = None
        leftNei = None
        if(r >= 1 and office_map[r-1, c] != 0):
            upperNei = out_map[r-1][c]
        if (c >= 1 and office_map[r, c-1] != 0):
            leftNei = out_map[r][c-1]
        if office_map[r,c] == 1: # Dev
            dev = getBestDev(devsLeft, upperNei, leftNei)
            dev.coord = [r,c]
            out_map[r].append(dev)
            score += dev.getScoreWith(upperNei) + dev.getScoreWith(leftNei)
        if office_map[r,c] == 2: # Manager
            man = getBestMan(mansLeft, upperNei, leftNei)
            man.coord = [r,c]
            out_map[r].append(man)
            score += man.getScoreWith(upperNei) + man.getScoreWith(leftNei)
        if office_map[r,c] == 0:
            out_map[r].append('X')
# Out:
# <__main__.Developer object at 0x000001EB26B4FB00>
# <__main__.ProjectManager object at 0x000001EB274CCDA0>
# <__main__.Developer object at 0x000001EB26B71390>
# <__main__.Developer object at 0x000001EB26D72390>
# <__main__.Developer object at 0x000001EB26B565F8>
# <__main__.Developer object at 0x000001EB26B85F60>
# <__main__.Developer object at 0x000001EB26D9EAC8>
# <__main__.Developer object at 0x000001EB26B9F7F0>
# <__main__.Developer object at 0x000001EB26BA09E8>
# <__main__.Developer object at 0x000001EB26DCD278>
# <__main__.Developer object at 0x000001EB26D14F98>
# <__main__.Developer object at 0x000001EB270DABA8>
# <__main__.Developer object at 0x000001EB26B9CCC0>
# <__main__.Developer object at 0x000001EB26E28240>
# <__main__.Developer object at 0x000001EB27370588>
# <__main__.Developer object at 0x000001EB26C4D6D8>
# <__main__.ProjectManager object at 0x000001EB274CAEF0>
# <__main__.Developer object at 0x000001EB26CE8BE0>
# <__main__.Developer object at 0x000001EB272474E0>
# <__main__.Developer object at 0x000001EB26D21940>
# <__main__.Developer object at 0x000001EB26B97390>
# <__main__.Developer object at 0x000001EB26FA4048>
# <__main__.Developer object at 0x000001EB26B916A0>
# <__main__.Developer object at 0x000001EB2726C0B8>
# <__main__.Developer object at 0x000001EB26FCBC50>
# <__main__.Developer object at 0x000001EB26CC1E80>
# <__main__.Developer object at 0x000001EB26B92CC0>
# <__main__.Developer object at 0x000001EB27081E80>
# <__main__.Developer object at 0x000001EB26B87978>
# <__main__.Developer object at 0x000001EB27357B38>
# <__main__.Developer object at 0x000001EB2701A048>
# <__main__.Developer object at 0x000001EB2700FBA8>
# <__main__.Developer object at 0x000001EB273ACE80>
# <__main__.Developer object at 0x000001EB26D20048>
# <__main__.Developer object at 0x000001EB26BA2208>
# <__main__.Developer object at 0x000001EB26ECEF98>
# <__main__.Developer object at 0x000001EB26BE79E8>
# <__main__.Developer object at 0x000001EB26B835C0>
# <__main__.Developer object at 0x000001EB26F80208>
# <__main__.Developer object at 0x000001EB26BAA5F8>
# <__main__.Developer object at 0x000001EB27230C88>
# <__main__.Developer object at 0x000001EB26CB5940>
# <__main__.ProjectManager object at 0x000001EB274BFC50>
# <__main__.Developer object at 0x000001EB26CB5588>
# <__main__.Developer object at 0x000001EB27067908>
# <__main__.Developer object at 0x000001EB26BAD748>
# <__main__.Developer object at 0x000001EB26FF9518>
# <__main__.Developer object at 0x000001EB26EDF8D0>
# <__main__.Developer object at 0x000001EB270EF630>
# <__main__.Developer object at 0x000001EB26CB3390>
# <__main__.Developer object at 0x000001EB26C71128>
# <__main__.Developer object at 0x000001EB27211E10>
# <__main__.Developer object at 0x000001EB26D91B70>
# <__main__.Developer object at 0x000001EB26ED9F60>
# <__main__.Developer object at 0x000001EB26C91EF0>
# <__main__.Developer object at 0x000001EB27244208>
# <__main__.Developer object at 0x000001EB26BB5C50>
# <__main__.Developer object at 0x000001EB27140A20>
# <__main__.ProjectManager object at 0x000001EB274C7E80>
# <__main__.Developer object at 0x000001EB26BC2DA0>
# <__main__.Developer object at 0x000001EB2729AA20>
# <__main__.Developer object at 0x000001EB27063F28>
# <__main__.Developer object at 0x000001EB26C28DD8>
# <__main__.Developer object at 0x000001EB26BB8160>
# <__main__.Developer object at 0x000001EB26EC60B8>
# <__main__.Developer object at 0x000001EB26C0DD68>
# <__main__.Developer object at 0x000001EB26D36CC0>
# <__main__.Developer object at 0x000001EB26BB9898>
# <__main__.Developer object at 0x000001EB271EB518>
# <__main__.Developer object at 0x000001EB26C91748>
# <__main__.Developer object at 0x000001EB273FC9B0>
# <__main__.Developer object at 0x000001EB26B83710>
# <__main__.Developer object at 0x000001EB26D558D0>
# <__main__.Developer object at 0x000001EB26E7E5C0>
# <__main__.ProjectManager object at 0x000001EB274D64A8>
# <__main__.Developer object at 0x000001EB26F13588>
# <__main__.Developer object at 0x000001EB26FB7358>
# <__main__.Developer object at 0x000001EB26BFC080>
# <__main__.Developer object at 0x000001EB26D5A978>
# <__main__.ProjectManager object at 0x000001EB274EE668>
# <__main__.Developer object at 0x000001EB27147860>
# <__main__.Developer object at 0x000001EB27312208>
# <__main__.Developer object at 0x000001EB2742CC88>
# <__main__.Developer object at 0x000001EB27226C18>
# <__main__.Developer object at 0x000001EB2748C5C0>
# <__main__.ProjectManager object at 0x000001EB274EEFD0>
# <__main__.Developer object at 0x000001EB2712AFD0>
# <__main__.Developer object at 0x000001EB26D470B8>
# <__main__.Developer object at 0x000001EB27320E80>
# <__main__.Developer object at 0x000001EB2738EC88>
# <__main__.Developer object at 0x000001EB26BC3A20>
# <__main__.Developer object at 0x000001EB26D1E9E8>
# <__main__.Developer object at 0x000001EB26BD54E0>
# <__main__.Developer object at 0x000001EB2719BAC8>
# <__main__.Developer object at 0x000001EB2711E780>
# <__main__.Developer object at 0x000001EB26E335F8>
# <__main__.Developer object at 0x000001EB26F355F8>
# <__main__.Developer object at 0x000001EB272A0978>
# <__main__.Developer object at 0x000001EB26FA4898>
# <__main__.Developer object at 0x000001EB26E66358>
# <__main__.Developer object at 0x000001EB27374240>
# <__main__.Developer object at 0x000001EB27412F28>
# <__main__.ProjectManager object at 0x000001EB274F40F0>
# <__main__.Developer object at 0x000001EB26E844E0>
# <__main__.Developer object at 0x000001EB274B4438>
# <__main__.Developer object at 0x000001EB26D66B00>
# <__main__.ProjectManager object at 0x000001EB274F6400>
# <__main__.Developer object at 0x000001EB26CED438>
# <__main__.Developer object at 0x000001EB26D36F28>
# <__main__.Developer object at 0x000001EB26ED7DD8>
# <__main__.Developer object at 0x000001EB27377048>
# <__main__.Developer object at 0x000001EB26DE59E8>
# <__main__.Developer object at 0x000001EB2721FE80>
# <__main__.Developer object at 0x000001EB26F12828>
# <__main__.Developer object at 0x000001EB273A1940>
# <__main__.Developer object at 0x000001EB27345198>
# <__main__.Developer object at 0x000001EB26CD86A0>
# <__main__.Developer object at 0x000001EB26FEF320>
# <__main__.ProjectManager object at 0x000001EB274C6C50>
# <__main__.Developer object at 0x000001EB273E6390>
# <__main__.Developer object at 0x000001EB270A15F8>
# <__main__.Developer object at 0x000001EB26DECE48>
# <__main__.Developer object at 0x000001EB26D600B8>
# <__main__.Developer object at 0x000001EB26CC8E48>
# <__main__.Developer object at 0x000001EB26BDF9E8>
# <__main__.Developer object at 0x000001EB273710F0>
# <__main__.Developer object at 0x000001EB26F593C8>
# <__main__.Developer object at 0x000001EB26D299E8>
# <__main__.Developer object at 0x000001EB270E47F0>
# <__main__.Developer object at 0x000001EB26E60BE0>
# <__main__.ProjectManager object at 0x000001EB274E90B8>
# <__main__.Developer object at 0x000001EB272B3860>
# <__main__.ProjectManager object at 0x000001EB274FD400>
# <__main__.Developer object at 0x000001EB271DB128>
# <__main__.Developer object at 0x000001EB26E00B00>
# <__main__.Developer object at 0x000001EB270C7D30>
# <__main__.Developer object at 0x000001EB26FCCF98>
# <__main__.ProjectManager object at 0x000001EB274F10F0>
# <__main__.ProjectManager object at 0x000001EB274F19B0>
# <__main__.Developer object at 0x000001EB271A0470>
# <__main__.Developer object at 0x000001EB270CFCF8>
# <__main__.Developer object at 0x000001EB26F54828>
# <__main__.Developer object at 0x000001EB273D3A90>
# <__main__.Developer object at 0x000001EB26FBBB38>
# <__main__.Developer object at 0x000001EB26BDFD68>
# <__main__.Developer object at 0x000001EB26C98F98>
# <__main__.Developer object at 0x000001EB27439240>
# <__main__.Developer object at 0x000001EB2716D6D8>
# <__main__.Developer object at 0x000001EB26F9B7B8>
# <__main__.Developer object at 0x000001EB273296A0>
# <__main__.Developer object at 0x000001EB272A9DD8>
# <__main__.Developer object at 0x000001EB26DA93C8>
# <__main__.Developer object at 0x000001EB26BFEC50>
# <__main__.Developer object at 0x000001EB26E570F0>
# <__main__.Developer object at 0x000001EB27101978>
# <__main__.Developer object at 0x000001EB27295D30>
# <__main__.Developer object at 0x000001EB26E20D30>
# <__main__.Developer object at 0x000001EB2718A2B0>
# <__main__.Developer object at 0x000001EB27432F60>
# <__main__.Developer object at 0x000001EB26BDD080>
# <__main__.Developer object at 0x000001EB26BE3E80>
# <__main__.Developer object at 0x000001EB27225E80>
# <__main__.Developer object at 0x000001EB272FEC18>
# <__main__.Developer object at 0x000001EB2702A0F0>
# <__main__.Developer object at 0x000001EB27307898>
# <__main__.Developer object at 0x000001EB26BFE908>
# <__main__.Developer object at 0x000001EB26DCF198>
# <__main__.Developer object at 0x000001EB26EFD668>
# <__main__.Developer object at 0x000001EB2711A208>
# <__main__.Developer object at 0x000001EB27381A20>
# <__main__.Developer object at 0x000001EB26DE2A20>
# <__main__.Developer object at 0x000001EB270869B0>
# <__main__.Developer object at 0x000001EB27090CF8>
# <__main__.Developer object at 0x000001EB273FBEB8>
# <__main__.Developer object at 0x000001EB26C6E358>
# <__main__.Developer object at 0x000001EB26C0D2E8>
# <__main__.Developer object at 0x000001EB26BE6D30>
# <__main__.Developer object at 0x000001EB26C70C18>
# <__main__.ProjectManager object at 0x000001EB26AE5B70>
# <__main__.Developer object at 0x000001EB26BE7048>
# <__main__.Developer object at 0x000001EB27009470>
# <__main__.Developer object at 0x000001EB27312A90>
# <__main__.Developer object at 0x000001EB271912B0>
# <__main__.Developer object at 0x000001EB26E2FB00>
# <__main__.Developer object at 0x000001EB271183C8>
# <__main__.Developer object at 0x000001EB26DB31D0>
# <__main__.ProjectManager object at 0x000001EB274D3C18>
# <__main__.Developer object at 0x000001EB26D8D7B8>
# <__main__.Developer object at 0x000001EB2716C978>
# <__main__.Developer object at 0x000001EB27125588>
# <__main__.Developer object at 0x000001EB26C55860>
# <__main__.Developer object at 0x000001EB272C3E48>
# <__main__.Developer object at 0x000001EB27133D68>
# <__main__.Developer object at 0x000001EB274B5D30>
# <__main__.Developer object at 0x000001EB273CA908>
# <__main__.Developer object at 0x000001EB26FAD240>
# <__main__.Developer object at 0x000001EB26E2E2B0>
# <__main__.Developer object at 0x000001EB274427F0>
# <__main__.Developer object at 0x000001EB26FF3208>
# <__main__.Developer object at 0x000001EB271767B8>
# <__main__.Developer object at 0x000001EB26BAA908>
# <__main__.Developer object at 0x000001EB274597B8>
# <__main__.Developer object at 0x000001EB271FF588>
# <__main__.Developer object at 0x000001EB2711DF60>
# <__main__.Developer object at 0x000001EB26C85438>
# <__main__.Developer object at 0x000001EB26D9DA58>
# <__main__.Developer object at 0x000001EB26E989E8>
# <__main__.Developer object at 0x000001EB26BF4240>
# <__main__.ProjectManager object at 0x000001EB2750D710>
# <__main__.Developer object at 0x000001EB270ECD30>
# <__main__.Developer object at 0x000001EB26E11780>
# <__main__.Developer object at 0x000001EB27301AC8>
# <__main__.Developer object at 0x000001EB26C6C3C8>
# <__main__.Developer object at 0x000001EB26BE7DA0>
# <__main__.Developer object at 0x000001EB2734FF98>
# <__main__.Developer object at 0x000001EB273C5908>
# <__main__.Developer object at 0x000001EB273F70B8>
# <__main__.Developer object at 0x000001EB2706F668>
# <__main__.Developer object at 0x000001EB26E76A58>
# <__main__.Developer object at 0x000001EB26DA8710>
# <__main__.Developer object at 0x000001EB26EE0978>
# <__main__.Developer object at 0x000001EB27483828>
# <__main__.Developer object at 0x000001EB273B7AC8>
# <__main__.Developer object at 0x000001EB270A3438>
# <__main__.Developer object at 0x000001EB26F5C710>
# <__main__.Developer object at 0x000001EB26E7B470>
# <__main__.Developer object at 0x000001EB26D3B978>
# <__main__.Developer object at 0x000001EB26CDAAC8>
# <__main__.Developer object at 0x000001EB2737A550>
# <__main__.Developer object at 0x000001EB26C977B8>
# <__main__.Developer object at 0x000001EB2711BDA0>
# <__main__.Developer object at 0x000001EB2729D198>
# <__main__.Developer object at 0x000001EB26FF9DA0>
# <__main__.Developer object at 0x000001EB271C87B8>
# <__main__.Developer object at 0x000001EB26D38438>
# <__main__.Developer object at 0x000001EB273C80B8>
# <__main__.Developer object at 0x000001EB2701E588>
# <__main__.Developer object at 0x000001EB2712EC50>
# <__main__.Developer object at 0x000001EB2702E8D0>
# <__main__.Developer object at 0x000001EB272AC4A8>
# <__main__.Developer object at 0x000001EB2705E128>
# <__main__.Developer object at 0x000001EB27477128>
# <__main__.Developer object at 0x000001EB27048E48>
# <__main__.Developer object at 0x000001EB26DB3E80>
# <__main__.ProjectManager object at 0x000001EB274CE160>
# <__main__.ProjectManager object at 0x000001EB27505E80>
# <__main__.Developer object at 0x000001EB26CA8FD0>
# <__main__.Developer object at 0x000001EB271D65F8>
# <__main__.Developer object at 0x000001EB26F2C4E0>
# <__main__.Developer object at 0x000001EB26C60B00>
# <__main__.Developer object at 0x000001EB27446AC8>
# <__main__.Developer object at 0x000001EB26D48C88>
# <__main__.Developer object at 0x000001EB26D0DD68>
# <__main__.Developer object at 0x000001EB27301EB8>
# <__main__.Developer object at 0x000001EB26E6A518>
# <__main__.Developer object at 0x000001EB2713CC50>
# <__main__.Developer object at 0x000001EB27277E48>
# <__main__.ProjectManager object at 0x000001EB274DDE48>
# <__main__.Developer object at 0x000001EB26F23390>
# <__main__.Developer object at 0x000001EB26BED0B8>
# <__main__.Developer object at 0x000001EB27280710>
# <__main__.Developer object at 0x000001EB2715F588>
# <__main__.Developer object at 0x000001EB2720B3C8>
# <__main__.Developer object at 0x000001EB273FF908>
# <__main__.Developer object at 0x000001EB26FE6F60>
# <__main__.Developer object at 0x000001EB26C12F98>
# <__main__.Developer object at 0x000001EB272A6AC8>
# <__main__.Developer object at 0x000001EB271614A8>
# <__main__.Developer object at 0x000001EB26CAE940>
# <__main__.Developer object at 0x000001EB26E98DD8>
# <__main__.Developer object at 0x000001EB27467940>
# <__main__.Developer object at 0x000001EB26F2C128>
# <__main__.Developer object at 0x000001EB27058EF0>
# <__main__.Developer object at 0x000001EB270908D0>
# <__main__.ProjectManager object at 0x000001EB27505320>
# <__main__.Developer object at 0x000001EB26B7B198>
# <__main__.Developer object at 0x000001EB26F804E0>
# <__main__.Developer object at 0x000001EB26BE9DA0>
# <__main__.Developer object at 0x000001EB2735CE80>
# <__main__.ProjectManager object at 0x000001EB274F6940>
# <__main__.Developer object at 0x000001EB2706FE48>
# <__main__.Developer object at 0x000001EB27003588>
# <__main__.Developer object at 0x000001EB26ED79B0>
# <__main__.Developer object at 0x000001EB26E815F8>
# <__main__.Developer object at 0x000001EB270DEDA0>
# <__main__.Developer object at 0x000001EB27213F60>
# <__main__.ProjectManager object at 0x000001EB27505D30>
# <__main__.Developer object at 0x000001EB26BF6160>
# <__main__.Developer object at 0x000001EB26BED470>
# <__main__.Developer object at 0x000001EB26CFE9B0>
# <__main__.Developer object at 0x000001EB26F51748>
# <__main__.Developer object at 0x000001EB27042940>
# <__main__.Developer object at 0x000001EB273B0898>
# <__main__.Developer object at 0x000001EB273BFA90>
# <__main__.Developer object at 0x000001EB26E30B70>
# <__main__.Developer object at 0x000001EB26F0C390>
# <__main__.Developer object at 0x000001EB2730CC88>
# <__main__.Developer object at 0x000001EB26BEF940>
# <__main__.Developer object at 0x000001EB26E2F278>
# <__main__.Developer object at 0x000001EB26E8BA58>
# <__main__.Developer object at 0x000001EB26F86E48>
# <__main__.Developer object at 0x000001EB26DF0A58>
# <__main__.Developer object at 0x000001EB2740AA90>
# <__main__.Developer object at 0x000001EB26F6B0F0>
# <__main__.Developer object at 0x000001EB26D40828>
# <__main__.Developer object at 0x000001EB26E52E10>
# <__main__.Developer object at 0x000001EB272D1908>
# <__main__.ProjectManager object at 0x000001EB274BEE48>
# <__main__.Developer object at 0x000001EB26BB0588>
# <__main__.Developer object at 0x000001EB27360198>
# <__main__.Developer object at 0x000001EB27375828>
# <__main__.Developer object at 0x000001EB26D45C18>
# <__main__.Developer object at 0x000001EB2746BBE0>
# <__main__.Developer object at 0x000001EB26C00898>
# <__main__.Developer object at 0x000001EB26BEFD68>
# <__main__.Developer object at 0x000001EB27096518>
# <__main__.Developer object at 0x000001EB273022E8>
# <__main__.Developer object at 0x000001EB2717F128>
# <__main__.Developer object at 0x000001EB26F3CA90>
# <__main__.Developer object at 0x000001EB27058A90>
# <__main__.Developer object at 0x000001EB26F48898>
# <__main__.Developer object at 0x000001EB26EE3160>
# <__main__.Developer object at 0x000001EB272A0198>
# <__main__.ProjectManager object at 0x000001EB274EBAC8>
# <__main__.ProjectManager object at 0x000001EB274CAE80>
# <__main__.Developer object at 0x000001EB26BE6550>
# <__main__.Developer object at 0x000001EB26D7F0F0>
# <__main__.Developer object at 0x000001EB27080AC8>
# <__main__.Developer object at 0x000001EB27380080>
# <__main__.Developer object at 0x000001EB2724B438>
# <__main__.Developer object at 0x000001EB273F97B8>
# <__main__.Developer object at 0x000001EB27374668>
# <__main__.Developer object at 0x000001EB272247B8>
# <__main__.Developer object at 0x000001EB26E91898>
# <__main__.Developer object at 0x000001EB26BF74A8>
# <__main__.Developer object at 0x000001EB26CA87F0>
# <__main__.Developer object at 0x000001EB26CD9128>
# <__main__.ProjectManager object at 0x000001EB274EBEB8>
# <__main__.Developer object at 0x000001EB26C29F98>
# <__main__.Developer object at 0x000001EB26D631D0>
# <__main__.Developer object at 0x000001EB26FBAE80>
# <__main__.Developer object at 0x000001EB272970F0>
# <__main__.Developer object at 0x000001EB273EDD30>
# <__main__.Developer object at 0x000001EB26E162E8>
# <__main__.Developer object at 0x000001EB270CAE80>
# <__main__.Developer object at 0x000001EB26C092B0>
# <__main__.Developer object at 0x000001EB26BC53C8>
# <__main__.Developer object at 0x000001EB26DED6D8>
# <__main__.ProjectManager object at 0x000001EB27505710>
# <__main__.Developer object at 0x000001EB26EFCEF0>
# <__main__.Developer object at 0x000001EB2745BFD0>
# <__main__.Developer object at 0x000001EB26BFA080>
# <__main__.Developer object at 0x000001EB2712A470>
# <__main__.Developer object at 0x000001EB271C1160>
# <__main__.Developer object at 0x000001EB26D5AE48>
# <__main__.Developer object at 0x000001EB26F07F60>
# <__main__.Developer object at 0x000001EB273BBBE0>
# <__main__.Developer object at 0x000001EB26BB8630>
# <__main__.Developer object at 0x000001EB271A7748>
# <__main__.ProjectManager object at 0x000001EB274C7160>
# <__main__.Developer object at 0x000001EB2714BB00>
# <__main__.Developer object at 0x000001EB26BFA978>
# <__main__.Developer object at 0x000001EB27324B38>
# <__main__.Developer object at 0x000001EB272EA438>
# <__main__.Developer object at 0x000001EB27013588>
# <__main__.Developer object at 0x000001EB26E06BE0>
# <__main__.Developer object at 0x000001EB272111D0>
# <__main__.ProjectManager object at 0x000001EB274F4BE0>
# <__main__.Developer object at 0x000001EB26DE8AC8>
# <__main__.Developer object at 0x000001EB271E3908>
# <__main__.Developer object at 0x000001EB26DBBDD8>
# <__main__.Developer object at 0x000001EB26FD8EF0>
# <__main__.Developer object at 0x000001EB26B88C18>
# <__main__.Developer object at 0x000001EB27301080>
# <__main__.Developer object at 0x000001EB272EE908>
# <__main__.Developer object at 0x000001EB26EF6898>
# <__main__.Developer object at 0x000001EB26C365F8>
# <__main__.Developer object at 0x000001EB272F4438>
# <__main__.Developer object at 0x000001EB2700BF60>
# <__main__.Developer object at 0x000001EB273C2358>
# <__main__.Developer object at 0x000001EB272717B8>
# <__main__.Developer object at 0x000001EB26D5D2B0>
# <__main__.ProjectManager object at 0x000001EB274BF940>
# <__main__.Developer object at 0x000001EB26DC1160>
# <__main__.Developer object at 0x000001EB26E86710>
# <__main__.ProjectManager object at 0x000001EB274C34E0>
# <__main__.Developer object at 0x000001EB2709BF60>
# <__main__.Developer object at 0x000001EB272B0550>
# <__main__.Developer object at 0x000001EB26F86240>
# <__main__.Developer object at 0x000001EB26C45C18>
# <__main__.ProjectManager object at 0x000001EB274C10F0>
# <__main__.Developer object at 0x000001EB2742A668>
# <__main__.Developer object at 0x000001EB270224A8>
# <__main__.Developer object at 0x000001EB26F0DE80>
# <__main__.Developer object at 0x000001EB2731A240>
# <__main__.Developer object at 0x000001EB273CBA20>
# <__main__.Developer object at 0x000001EB26C77390>
# <__main__.Developer object at 0x000001EB27435550>
# <__main__.Developer object at 0x000001EB26C03E80>
# <__main__.Developer object at 0x000001EB2705B048>
# <__main__.Developer object at 0x000001EB26FF53C8>
# <__main__.Developer object at 0x000001EB27036668>
# <__main__.Developer object at 0x000001EB271188D0>
# <__main__.Developer object at 0x000001EB2737D438>
# <__main__.Developer object at 0x000001EB26F458D0>
# <__main__.Developer object at 0x000001EB2705C358>
# <__main__.ProjectManager object at 0x000001EB274C14E0>
# <__main__.Developer object at 0x000001EB26CEA208>
# <__main__.Developer object at 0x000001EB26BE3240>
# <__main__.Developer object at 0x000001EB2747AB70>
# <__main__.ProjectManager object at 0x000001EB274BFA90>
# <__main__.Developer object at 0x000001EB26D5F7F0>
# <__main__.Developer object at 0x000001EB26C8B390>
# <__main__.Developer object at 0x000001EB271AADD8>
# <__main__.Developer object at 0x000001EB26F81630>
# <__main__.Developer object at 0x000001EB270CC240>
# <__main__.Developer object at 0x000001EB26CADBE0>
# <__main__.Developer object at 0x000001EB26CEB940>
# <__main__.Developer object at 0x000001EB26F6B828>
# <__main__.Developer object at 0x000001EB26C0A208>
# <__main__.Developer object at 0x000001EB26D942E8>
# <__main__.Developer object at 0x000001EB27043198>
# <__main__.Developer object at 0x000001EB273111D0>
# <__main__.Developer object at 0x000001EB26A51400>
# <__main__.Developer object at 0x000001EB26CED940>
# <__main__.Developer object at 0x000001EB26EADC88>
# <__main__.Developer object at 0x000001EB272D0C88>
# <__main__.Developer object at 0x000001EB26FA4BE0>
# <__main__.Developer object at 0x000001EB26C0EE10>
# <__main__.Developer object at 0x000001EB26E21D30>
# <__main__.Developer object at 0x000001EB27026278>
# <__main__.Developer object at 0x000001EB27387C18>
# <__main__.Developer object at 0x000001EB272CFC18>
# <__main__.Developer object at 0x000001EB26F5E780>
# <__main__.Developer object at 0x000001EB26CFAB70>
# <__main__.Developer object at 0x000001EB27000160>
# <__main__.Developer object at 0x000001EB26B30940>
# <__main__.Developer object at 0x000001EB2717EC18>
# <__main__.Developer object at 0x000001EB26FA6780>
# <__main__.Developer object at 0x000001EB27060208>
# <__main__.Developer object at 0x000001EB26F7C198>
# <__main__.Developer object at 0x000001EB26C51E80>
# <__main__.Developer object at 0x000001EB271A26D8>
# <__main__.Developer object at 0x000001EB2702ED30>
# <__main__.Developer object at 0x000001EB2716F438>
# <__main__.Developer object at 0x000001EB27148898>
# <__main__.ProjectManager object at 0x000001EB274F4FD0>
# <__main__.Developer object at 0x000001EB272356A0>
# <__main__.ProjectManager object at 0x000001EB274F6EF0>
# <__main__.Developer object at 0x000001EB26C8CF60>
# <__main__.ProjectManager object at 0x000001EB274DBEB8>
# <__main__.Developer object at 0x000001EB26D45358>
# <__main__.Developer object at 0x000001EB271355C0>
# <__main__.ProjectManager object at 0x000001EB274C3B00>
# <__main__.Developer object at 0x000001EB2743E630>
# <__main__.Developer object at 0x000001EB273790B8>
# <__main__.Developer object at 0x000001EB26E346A0>
# <__main__.Developer object at 0x000001EB271872B0>
# <__main__.Developer object at 0x000001EB26C820B8>
# <__main__.ProjectManager object at 0x000001EB274EE048>
# <__main__.Developer object at 0x000001EB270F3390>
# <__main__.Developer object at 0x000001EB271F2E10>
# <__main__.Developer object at 0x000001EB2702DE80>
# <__main__.Developer object at 0x000001EB26E63E48>
# <__main__.Developer object at 0x000001EB26C102B0>
# <__main__.Developer object at 0x000001EB26D27B00>
# <__main__.Developer object at 0x000001EB2739E518>
# <__main__.Developer object at 0x000001EB271AA6A0>
# <__main__.Developer object at 0x000001EB26BA6CC0>
# <__main__.Developer object at 0x000001EB26C7C400>
# <__main__.Developer object at 0x000001EB27135DA0>
# <__main__.Developer object at 0x000001EB2716D470>
# <__main__.ProjectManager object at 0x000001EB274DB2E8>
# <__main__.Developer object at 0x000001EB2715F908>
# <__main__.Developer object at 0x000001EB273F2588>
# <__main__.Developer object at 0x000001EB26CEF6A0>
# <__main__.Developer object at 0x000001EB27398400>
# <__main__.ProjectManager object at 0x000001EB274EBC18>
# <__main__.Developer object at 0x000001EB274748D0>
# <__main__.Developer object at 0x000001EB27227AC8>
# <__main__.ProjectManager object at 0x000001EB274CE6A0>
# <__main__.Developer object at 0x000001EB271D3B00>
# <__main__.Developer object at 0x000001EB2730F6D8>
# <__main__.Developer object at 0x000001EB27374FD0>
# <__main__.Developer object at 0x000001EB274472B0>
# <__main__.Developer object at 0x000001EB26BAD400>
# <__main__.Developer object at 0x000001EB2714CE10>
# <__main__.Developer object at 0x000001EB272F3F98>
# <__main__.ProjectManager object at 0x000001EB274CA8D0>
# <__main__.Developer object at 0x000001EB26E91438>
# <__main__.Developer object at 0x000001EB270F4320>
# <__main__.ProjectManager object at 0x000001EB274EE828>
# <__main__.Developer object at 0x000001EB27260BA8>
# <__main__.Developer object at 0x000001EB271576D8>
# <__main__.Developer object at 0x000001EB2704B3C8>
# <__main__.Developer object at 0x000001EB26B7DB70>
# <__main__.Developer object at 0x000001EB272EAFD0>
# <__main__.Developer object at 0x000001EB270E82E8>
# <__main__.ProjectManager object at 0x000001EB274EECF8>
# <__main__.Developer object at 0x000001EB26E6F940>
# <__main__.Developer object at 0x000001EB27282D30>
# <__main__.Developer object at 0x000001EB2726F0F0>
# <__main__.Developer object at 0x000001EB273DB400>
# <__main__.Developer object at 0x000001EB26C14C88>
# <__main__.Developer object at 0x000001EB272A4668>
# <__main__.Developer object at 0x000001EB27461160>
# <__main__.Developer object at 0x000001EB26FBB160>
# <__main__.Developer object at 0x000001EB26D48978>
# <__main__.Developer object at 0x000001EB272304E0>
# <__main__.Developer object at 0x000001EB27484E48>
# <__main__.Developer object at 0x000001EB26E52668>
# <__main__.ProjectManager object at 0x000001EB275165C0>
# <__main__.Developer object at 0x000001EB27414400>
# <__main__.Developer object at 0x000001EB272FCFD0>
# <__main__.Developer object at 0x000001EB270B27B8>
# <__main__.Developer object at 0x000001EB27167518>
# <__main__.Developer object at 0x000001EB272919B0>
# <__main__.Developer object at 0x000001EB26C215F8>
# <__main__.Developer object at 0x000001EB27142160>
# <__main__.Developer object at 0x000001EB26E06780>
# <__main__.Developer object at 0x000001EB272E8588>
# <__main__.Developer object at 0x000001EB26E4E2E8>
# <__main__.Developer object at 0x000001EB2713D550>
# <__main__.Developer object at 0x000001EB2708AE48>
# <__main__.Developer object at 0x000001EB26CBF668>
# <__main__.ProjectManager object at 0x000001EB275036A0>
# <__main__.Developer object at 0x000001EB26D619E8>
# <__main__.Developer object at 0x000001EB273BC0F0>
# <__main__.Developer object at 0x000001EB2731C3C8>
# <__main__.Developer object at 0x000001EB27326C18>
# <__main__.Developer object at 0x000001EB26F3B390>
# <__main__.Developer object at 0x000001EB271EF828>
# <__main__.Developer object at 0x000001EB27348748>
# <__main__.Developer object at 0x000001EB26C4A550>
# <__main__.Developer object at 0x000001EB26C53F98>
# <__main__.Developer object at 0x000001EB2704A048>
# <__main__.Developer object at 0x000001EB271C6D30>
# <__main__.Developer object at 0x000001EB26F6A6A0>
# <__main__.Developer object at 0x000001EB274814E0>
# <__main__.Developer object at 0x000001EB26DAD048>
# <__main__.Developer object at 0x000001EB272047F0>
# <__main__.Developer object at 0x000001EB26E93630>
# <__main__.Developer object at 0x000001EB26E28E80>
# <__main__.Developer object at 0x000001EB27426400>
# <__main__.Developer object at 0x000001EB26CF3978>
# <__main__.Developer object at 0x000001EB26C94FD0>
# <__main__.Developer object at 0x000001EB26F94320>
# <__main__.Developer object at 0x000001EB26DC7D30>
# <__main__.Developer object at 0x000001EB26BAC0B8>
# <__main__.Developer object at 0x000001EB26D96080>
# <__main__.Developer object at 0x000001EB272AF470>
# <__main__.Developer object at 0x000001EB26FD4CC0>
# <__main__.Developer object at 0x000001EB26E4E9E8>
# <__main__.Developer object at 0x000001EB273391D0>
# <__main__.Developer object at 0x000001EB272CC6A0>
# <__main__.Developer object at 0x000001EB26C10EF0>
# <__main__.Developer object at 0x000001EB270D6D68>
# <__main__.Developer object at 0x000001EB26F5F390>
# <__main__.Developer object at 0x000001EB26C261D0>
# <__main__.Developer object at 0x000001EB26E1B8D0>
# <__main__.Developer object at 0x000001EB26DD8160>
# <__main__.Developer object at 0x000001EB27078BE0>
# <__main__.ProjectManager object at 0x000001EB274FDBE0>
# <__main__.Developer object at 0x000001EB272ED4A8>
# <__main__.Developer object at 0x000001EB26CD8D30>
# <__main__.Developer object at 0x000001EB270FB160>
# <__main__.ProjectManager object at 0x000001EB274FF4E0>
# <__main__.Developer object at 0x000001EB26F9FE10>
# <__main__.Developer object at 0x000001EB26FDFA58>
# <__main__.Developer object at 0x000001EB271E5550>
# <__main__.ProjectManager object at 0x000001EB274D6588>
# <__main__.Developer object at 0x000001EB26C240B8>
# <__main__.Developer object at 0x000001EB26C27B00>
# <__main__.Developer object at 0x000001EB272E3630>
# <__main__.Developer object at 0x000001EB26EE5240>
# <__main__.Developer object at 0x000001EB26C40DA0>
# <__main__.Developer object at 0x000001EB2744D198>
# <__main__.Developer object at 0x000001EB2700DF98>
# <__main__.Developer object at 0x000001EB271658D0>
# <__main__.Developer object at 0x000001EB27095400>
# <__main__.Developer object at 0x000001EB26EBDDA0>
# <__main__.Developer object at 0x000001EB2730CF28>
# <__main__.Developer object at 0x000001EB26E007B8>
# <__main__.Developer object at 0x000001EB271D4898>
# <__main__.Developer object at 0x000001EB2735BCF8>
# <__main__.Developer object at 0x000001EB26E5F0F0>
# <__main__.Developer object at 0x000001EB26C282E8>
# <__main__.Developer object at 0x000001EB274B20F0>
# <__main__.Developer object at 0x000001EB2720B6D8>
# <__main__.Developer object at 0x000001EB2735F550>
# <__main__.Developer object at 0x000001EB273FAAC8>
# <__main__.Developer object at 0x000001EB272CE748>
# <__main__.Developer object at 0x000001EB2726EA20>
# <__main__.Developer object at 0x000001EB270B0F28>
# <__main__.Developer object at 0x000001EB2729F5F8>
# <__main__.Developer object at 0x000001EB26BE7518>
# <__main__.Developer object at 0x000001EB270619E8>
# <__main__.Developer object at 0x000001EB26DCC320>
# <__main__.Developer object at 0x000001EB26C4DE48>
# <__main__.Developer object at 0x000001EB273A66A0>
# <__main__.Developer object at 0x000001EB2704DBE0>
# <__main__.Developer object at 0x000001EB273BDB00>
# <__main__.Developer object at 0x000001EB270A5EF0>
# <__main__.Developer object at 0x000001EB26F1C588>
# <__main__.Developer object at 0x000001EB2718B908>
# <__main__.Developer object at 0x000001EB272CFF60>
# <__main__.Developer object at 0x000001EB26CE88D0>
# <__main__.Developer object at 0x000001EB26ECF940>
# <__main__.Developer object at 0x000001EB26CF30F0>
# <__main__.Developer object at 0x000001EB26C2E390>
# <__main__.Developer object at 0x000001EB274AC358>
# <__main__.Developer object at 0x000001EB26F99320>
# <__main__.Developer object at 0x000001EB26FB9EF0>
# <__main__.Developer object at 0x000001EB26D5B390>
# <__main__.Developer object at 0x000001EB26C99748>
# <__main__.Developer object at 0x000001EB26DF5AC8>
# <__main__.Developer object at 0x000001EB26C2F128>
# <__main__.ProjectManager object at 0x000001EB274E9C88>
# <__main__.Developer object at 0x000001EB26D59898>
# <__main__.Developer object at 0x000001EB26DFF9B0>
# <__main__.Developer object at 0x000001EB273067F0>
# <__main__.Developer object at 0x000001EB27327400>
# <__main__.Developer object at 0x000001EB26CB69B0>
# <__main__.Developer object at 0x000001EB26CAB390>
# <__main__.Developer object at 0x000001EB27354908>
# <__main__.Developer object at 0x000001EB26BEA860>
# <__main__.ProjectManager object at 0x000001EB274F12B0>
# <__main__.Developer object at 0x000001EB26C04128>
# <__main__.Developer object at 0x000001EB26B76C18>
# <__main__.Developer object at 0x000001EB27318EF0>
# <__main__.ProjectManager object at 0x000001EB274FA240>
# <__main__.Developer object at 0x000001EB26C71FD0>
# <__main__.Developer object at 0x000001EB271EF518>
# <__main__.Developer object at 0x000001EB27476908>
# <__main__.Developer object at 0x000001EB26E3FB70>
# <__main__.Developer object at 0x000001EB271193C8>
# <__main__.Developer object at 0x000001EB271F5390>
# <__main__.Developer object at 0x000001EB26DD8C88>
# <__main__.Developer object at 0x000001EB27403B38>
# <__main__.Developer object at 0x000001EB26C537B8>
# <__main__.Developer object at 0x000001EB274B8278>
# <__main__.Developer object at 0x000001EB26D7C278>
# <__main__.Developer object at 0x000001EB26BFB908>
# <__main__.Developer object at 0x000001EB26C32518>
# <__main__.Developer object at 0x000001EB26FBDC18>
# <__main__.Developer object at 0x000001EB26F5FE80>
# <__main__.Developer object at 0x000001EB2715BC88>
# <__main__.Developer object at 0x000001EB272A2EF0>
# <__main__.Developer object at 0x000001EB26F426A0>
# <__main__.Developer object at 0x000001EB26EDBCC0>
# <__main__.Developer object at 0x000001EB26B9AF28>
# <__main__.Developer object at 0x000001EB26CD1DA0>
# <__main__.Developer object at 0x000001EB2706A828>
# <__main__.Developer object at 0x000001EB26C36A20>
# <__main__.Developer object at 0x000001EB26C33208>
# <__main__.Developer object at 0x000001EB26CF0160>
# <__main__.Developer object at 0x000001EB26EF3240>
# <__main__.Developer object at 0x000001EB26F2D400>
# <__main__.Developer object at 0x000001EB26E771D0>
# <__main__.Developer object at 0x000001EB26D54208>
# <__main__.Developer object at 0x000001EB270C0DA0>
# <__main__.Developer object at 0x000001EB27083780>
# <__main__.Developer object at 0x000001EB2743D400>
# <__main__.Developer object at 0x000001EB26C7C748>
# <__main__.ProjectManager object at 0x000001EB26AE5518>
# <__main__.Developer object at 0x000001EB26B5A358>
# <__main__.ProjectManager object at 0x000001EB2750AEF0>
# <__main__.Developer object at 0x000001EB274713C8>
# <__main__.Developer object at 0x000001EB2743B320>
# <__main__.Developer object at 0x000001EB26E11A58>
# <__main__.Developer object at 0x000001EB26EC5D30>
# <__main__.Developer object at 0x000001EB26DBBAC8>
# <__main__.Developer object at 0x000001EB2706A400>
# <__main__.Developer object at 0x000001EB270311D0>
# <__main__.ProjectManager object at 0x000001EB274C3160>
# <__main__.Developer object at 0x000001EB26DB93C8>
# <__main__.Developer object at 0x000001EB270B1630>
# <__main__.Developer object at 0x000001EB26D2D5C0>
# <__main__.Developer object at 0x000001EB272094A8>
# <__main__.Developer object at 0x000001EB270D3550>
# <__main__.Developer object at 0x000001EB26B850B8>
# <__main__.Developer object at 0x000001EB270CB9E8>
# <__main__.Developer object at 0x000001EB272DBEB8>
# <__main__.Developer object at 0x000001EB26D6CA90>
# <__main__.Developer object at 0x000001EB26BD8F60>
# <__main__.Developer object at 0x000001EB273980F0>
# <__main__.Developer object at 0x000001EB26F76898>
# <__main__.ProjectManager object at 0x000001EB274C6710>
# <__main__.Developer object at 0x000001EB26F6FF60>
# <__main__.Developer object at 0x000001EB26EFC6A0>
# <__main__.ProjectManager object at 0x000001EB274FAE80>
# <__main__.ProjectManager object at 0x000001EB274D8358>
# <__main__.Developer object at 0x000001EB26F3DF60>
# <__main__.Developer object at 0x000001EB26B9F320>
# <__main__.Developer object at 0x000001EB26BBD048>
# <__main__.Developer object at 0x000001EB270123C8>
# <__main__.Developer object at 0x000001EB26DE8208>
# <__main__.Developer object at 0x000001EB26DD3630>
# <__main__.Developer object at 0x000001EB26DC5080>
# <__main__.Developer object at 0x000001EB26C38E80>
# <__main__.Developer object at 0x000001EB271B2B70>
# <__main__.Developer object at 0x000001EB26E58198>
# <__main__.Developer object at 0x000001EB27202D30>
# <__main__.Developer object at 0x000001EB26B83DD8>
# <__main__.Developer object at 0x000001EB26DD1E10>
# <__main__.Developer object at 0x000001EB26E9EA20>
# <__main__.Developer object at 0x000001EB271D1EB8>
# <__main__.Developer object at 0x000001EB271DAA20>
# <__main__.Developer object at 0x000001EB26FE6CF8>
# <__main__.Developer object at 0x000001EB26C64E80>
# <__main__.Developer object at 0x000001EB2730A3C8>
# <__main__.Developer object at 0x000001EB26CA2F28>
# <__main__.Developer object at 0x000001EB26F20780>
# <__main__.Developer object at 0x000001EB27022208>
# <__main__.Developer object at 0x000001EB26FD7588>
# <__main__.Developer object at 0x000001EB272C6898>
# <__main__.Developer object at 0x000001EB26C81D68>
# <__main__.Developer object at 0x000001EB270ACC50>
# <__main__.Developer object at 0x000001EB26F196A0>
# <__main__.Developer object at 0x000001EB26C035C0>
# <__main__.Developer object at 0x000001EB26DD1208>
# <__main__.ProjectManager object at 0x000001EB274D83C8>
# <__main__.Developer object at 0x000001EB26FB4898>
# <__main__.Developer object at 0x000001EB271F0668>
# <__main__.Developer object at 0x000001EB27195B38>
# <__main__.Developer object at 0x000001EB272C4940>
# <__main__.Developer object at 0x000001EB270B2F28>
# <__main__.Developer object at 0x000001EB272DA208>
# <__main__.Developer object at 0x000001EB273A4F98>
# <__main__.Developer object at 0x000001EB271E83C8>
# <__main__.Developer object at 0x000001EB2747A2B0>
# <__main__.Developer object at 0x000001EB27171160>
# <__main__.Developer object at 0x000001EB26F7DA90>
# <__main__.Developer object at 0x000001EB26F97668>
# <__main__.Developer object at 0x000001EB26E4A438>
# <__main__.Developer object at 0x000001EB27187E48>
# <__main__.Developer object at 0x000001EB26D29390>
# <__main__.Developer object at 0x000001EB26F18358>
# <__main__.Developer object at 0x000001EB26F7DDA0>
# <__main__.Developer object at 0x000001EB2713C7B8>
# <__main__.Developer object at 0x000001EB27347780>
# <__main__.Developer object at 0x000001EB26CA2128>
# <__main__.Developer object at 0x000001EB27148C50>
# <__main__.Developer object at 0x000001EB272CAE80>
# <__main__.Developer object at 0x000001EB26F03160>
# <__main__.Developer object at 0x000001EB26FBA6A0>
# <__main__.Developer object at 0x000001EB274A9FD0>
# <__main__.Developer object at 0x000001EB2707D940>
# <__main__.Developer object at 0x000001EB2724C898>
# <__main__.Developer object at 0x000001EB27455390>
# <__main__.Developer object at 0x000001EB26CDC630>
# <__main__.Developer object at 0x000001EB26E22668>
# <__main__.Developer object at 0x000001EB26FDF748>
# <__main__.Developer object at 0x000001EB26EBEE80>
# <__main__.Developer object at 0x000001EB27486A20>
# <__main__.Developer object at 0x000001EB26C469B0>
# <__main__.Developer object at 0x000001EB26F6D550>
# <__main__.Developer object at 0x000001EB26C35908>
# <__main__.Developer object at 0x000001EB26BB9B70>
# <__main__.Developer object at 0x000001EB2740AE48>
# <__main__.Developer object at 0x000001EB27459358>
# <__main__.Developer object at 0x000001EB26DDBBE0>
# <__main__.ProjectManager object at 0x000001EB274C1860>
# <__main__.Developer object at 0x000001EB26C2B668>
# <__main__.Developer object at 0x000001EB26BC8160>
# <__main__.Developer object at 0x000001EB26C1DD30>
# <__main__.Developer object at 0x000001EB26D5D588>
# <__main__.Developer object at 0x000001EB26EEECC0>
# <__main__.ProjectManager object at 0x000001EB27508FD0>
# <__main__.Developer object at 0x000001EB27377860>
# <__main__.Developer object at 0x000001EB271E4BA8>
# <__main__.Developer object at 0x000001EB26F76B70>
# <__main__.Developer object at 0x000001EB26EB2DA0>
# <__main__.Developer object at 0x000001EB26EDB828>
# <__main__.Developer object at 0x000001EB274921D0>
# <__main__.Developer object at 0x000001EB272EFEF0>
# <__main__.Developer object at 0x000001EB26FC7F60>
# <__main__.Developer object at 0x000001EB26EBD240>
# <__main__.Developer object at 0x000001EB26C86710>
# <__main__.Developer object at 0x000001EB26FA0E80>
# <__main__.Developer object at 0x000001EB26C400F0>
# <__main__.Developer object at 0x000001EB26F68668>
# <__main__.Developer object at 0x000001EB27197550>
# <__main__.Developer object at 0x000001EB27498A90>
# <__main__.Developer object at 0x000001EB26BABC18>
# <__main__.Developer object at 0x000001EB270A1A20>
# <__main__.Developer object at 0x000001EB26D03978>
# <__main__.Developer object at 0x000001EB2701B550>
# <__main__.Developer object at 0x000001EB273E6DD8>
# <__main__.Developer object at 0x000001EB272F64A8>
# <__main__.Developer object at 0x000001EB26DBE0F0>
# <__main__.Developer object at 0x000001EB27158438>
# <__main__.Developer object at 0x000001EB26DA4BA8>
# <__main__.Developer object at 0x000001EB26CF4BE0>
# <__main__.Developer object at 0x000001EB26C06320>
# <__main__.Developer object at 0x000001EB26F9F390>
# <__main__.Developer object at 0x000001EB270F6CF8>
# <__main__.Developer object at 0x000001EB27121D30>
# <__main__.Developer object at 0x000001EB26C27438>
# <__main__.Developer object at 0x000001EB27419710>
# <__main__.Developer object at 0x000001EB270B8D30>
# <__main__.Developer object at 0x000001EB26C457B8>
# <__main__.Developer object at 0x000001EB26E8F358>
# <__main__.Developer object at 0x000001EB270725F8>
# <__main__.ProjectManager object at 0x000001EB274BF630>
# <__main__.Developer object at 0x000001EB26BD8BA8>
# <__main__.Developer object at 0x000001EB270D82B0>
# <__main__.Developer object at 0x000001EB26E87710>
# <__main__.Developer object at 0x000001EB272C8358>
# <__main__.ProjectManager object at 0x000001EB274FD390>
# <__main__.Developer object at 0x000001EB26B7DFD0>
# <__main__.Developer object at 0x000001EB27424780>
# <__main__.Developer object at 0x000001EB26DE4F98>
# <__main__.Developer object at 0x000001EB27076400>
# <__main__.ProjectManager object at 0x000001EB274F6780>
# <__main__.Developer object at 0x000001EB27088B70>
# <__main__.Developer object at 0x000001EB26FD3A58>
# <__main__.Developer object at 0x000001EB26F7CE48>
# <__main__.Developer object at 0x000001EB270863C8>
# <__main__.Developer object at 0x000001EB272D7470>
# <__main__.Developer object at 0x000001EB26C12780>
# <__main__.Developer object at 0x000001EB271B20F0>
# <__main__.Developer object at 0x000001EB26DB6C50>
# <__main__.Developer object at 0x000001EB271FFEF0>
# <__main__.Developer object at 0x000001EB27490D30>
# <__main__.Developer object at 0x000001EB26EA1978>
# <__main__.Developer object at 0x000001EB26E129E8>
# <__main__.Developer object at 0x000001EB26D92F60>
# <__main__.Developer object at 0x000001EB27195748>
# <__main__.Developer object at 0x000001EB2715CFD0>
# <__main__.Developer object at 0x000001EB26B950B8>
# <__main__.ProjectManager object at 0x000001EB275087F0>
# <__main__.Developer object at 0x000001EB270F1668>
# <__main__.Developer object at 0x000001EB26C1B278>
# <__main__.Developer object at 0x000001EB26D49C50>
# <__main__.Developer object at 0x000001EB26F18668>
# <__main__.ProjectManager object at 0x000001EB274CAB70>
# <__main__.Developer object at 0x000001EB26C3BD68>
# <__main__.Developer object at 0x000001EB26F896A0>
# <__main__.Developer object at 0x000001EB26CCF160>
# <__main__.Developer object at 0x000001EB26EA56D8>
# <__main__.Developer object at 0x000001EB26DC44A8>
# <__main__.Developer object at 0x000001EB270CF978>
# <__main__.ProjectManager object at 0x000001EB274DD278>
# <__main__.Developer object at 0x000001EB26D07208>
# <__main__.Developer object at 0x000001EB26EF94A8>
# <__main__.Developer object at 0x000001EB26BB0BE0>
# <__main__.Developer object at 0x000001EB2727D198>
# <__main__.Developer object at 0x000001EB273BB7F0>
# <__main__.Developer object at 0x000001EB27248DD8>
# <__main__.Developer object at 0x000001EB27197048>
# <__main__.Developer object at 0x000001EB27050630>
# <__main__.Developer object at 0x000001EB27192668>
# <__main__.Developer object at 0x000001EB2732B1D0>
# <__main__.Developer object at 0x000001EB26F82EB8>
# <__main__.Developer object at 0x000001EB26C46DA0>
# <__main__.Developer object at 0x000001EB26D88390>
# <__main__.Developer object at 0x000001EB26DC47F0>
# <__main__.Developer object at 0x000001EB26C4A9B0>
# <__main__.Developer object at 0x000001EB26F71390>
# <__main__.Developer object at 0x000001EB26F55320>
# <__main__.Developer object at 0x000001EB26D006D8>
# <__main__.Developer object at 0x000001EB26D967B8>
# <__main__.Developer object at 0x000001EB270BE9E8>
# <__main__.Developer object at 0x000001EB26DE46D8>
# <__main__.Developer object at 0x000001EB26F4E438>
# <__main__.Developer object at 0x000001EB2725AFD0>
# <__main__.Developer object at 0x000001EB2736CB00>
# <__main__.Developer object at 0x000001EB27373B00>
# <__main__.Developer object at 0x000001EB26CA7FD0>
# <__main__.Developer object at 0x000001EB26FEF6A0>
# <__main__.Developer object at 0x000001EB270CB588>
# <__main__.Developer object at 0x000001EB26D54B00>
# <__main__.Developer object at 0x000001EB26BA3780>
# <__main__.Developer object at 0x000001EB26B716A0>
# <__main__.Developer object at 0x000001EB27487C88>
# <__main__.Developer object at 0x000001EB27014390>
# <__main__.Developer object at 0x000001EB26C4F898>
# <__main__.Developer object at 0x000001EB27469BE0>
# <__main__.Developer object at 0x000001EB27059CF8>
# <__main__.Developer object at 0x000001EB26F555F8>
# <__main__.Developer object at 0x000001EB26C67278>
# <__main__.Developer object at 0x000001EB26DBD630>
# <__main__.Developer object at 0x000001EB2719E588>
# <__main__.Developer object at 0x000001EB26EF1A58>
# <__main__.Developer object at 0x000001EB26DD3978>
# <__main__.Developer object at 0x000001EB270854E0>
# <__main__.Developer object at 0x000001EB27286780>
# <__main__.Developer object at 0x000001EB26B86438>
# <__main__.Developer object at 0x000001EB26F03F98>
# <__main__.Developer object at 0x000001EB26E82668>
# <__main__.Developer object at 0x000001EB270F8B70>
# <__main__.Developer object at 0x000001EB270A6358>
# <__main__.Developer object at 0x000001EB2721DF28>
# <__main__.Developer object at 0x000001EB26D41198>
# <__main__.Developer object at 0x000001EB26E26CF8>
# <__main__.Developer object at 0x000001EB27446048>
# <__main__.Developer object at 0x000001EB27086630>
# <__main__.Developer object at 0x000001EB2712F4E0>
# <__main__.ProjectManager object at 0x000001EB27505160>
# <__main__.Developer object at 0x000001EB26E7BD30>
# <__main__.Developer object at 0x000001EB27208B38>
# <__main__.Developer object at 0x000001EB26F20F98>
# <__main__.Developer object at 0x000001EB26BCCBA8>
# <__main__.Developer object at 0x000001EB26F276D8>
# <__main__.Developer object at 0x000001EB26C51B38>
# <__main__.Developer object at 0x000001EB273C8470>
# <__main__.Developer object at 0x000001EB273968D0>
# <__main__.Developer object at 0x000001EB26EF4EB8>
# <__main__.Developer object at 0x000001EB272265C0>
# <__main__.Developer object at 0x000001EB26FB2BE0>
# <__main__.Developer object at 0x000001EB26E25470>
# <__main__.Developer object at 0x000001EB272B9978>
# <__main__.Developer object at 0x000001EB26C120F0>
# <__main__.Developer object at 0x000001EB26D9EEB8>
# <__main__.Developer object at 0x000001EB26DAB3C8>
# <__main__.Developer object at 0x000001EB26D227F0>
# <__main__.Developer object at 0x000001EB27088898>
# <__main__.Developer object at 0x000001EB26E14AC8>
# <__main__.Developer object at 0x000001EB26EAF518>
# <__main__.Developer object at 0x000001EB26CA8B70>
# <__main__.Developer object at 0x000001EB26BE9B00>
# <__main__.Developer object at 0x000001EB26E92780>
# <__main__.Developer object at 0x000001EB26E45C88>
# <__main__.Developer object at 0x000001EB26E52978>
# <__main__.Developer object at 0x000001EB2714B0B8>
# <__main__.Developer object at 0x000001EB26F1EEF0>
# <__main__.Developer object at 0x000001EB26EEA550>
# <__main__.Developer object at 0x000001EB273A1470>
# <__main__.Developer object at 0x000001EB26CE0940>
# <__main__.Developer object at 0x000001EB26C5B438>
# <__main__.Developer object at 0x000001EB27178A90>
# <__main__.ProjectManager object at 0x000001EB274C3940>
# <__main__.Developer object at 0x000001EB270926A0>
# <__main__.Developer object at 0x000001EB2725E0B8>
# <__main__.Developer object at 0x000001EB273F8748>
# <__main__.Developer object at 0x000001EB27347BE0>
# <__main__.Developer object at 0x000001EB26EFE240>
# <__main__.Developer object at 0x000001EB27435A58>
# <__main__.Developer object at 0x000001EB272341D0>
# <__main__.Developer object at 0x000001EB27285B00>
# <__main__.Developer object at 0x000001EB2716BFD0>
# <__main__.Developer object at 0x000001EB26BEDE10>
# <__main__.Developer object at 0x000001EB2723D2B0>
# <__main__.Developer object at 0x000001EB26C5CBE0>
# <__main__.Developer object at 0x000001EB26FE1240>
# <__main__.Developer object at 0x000001EB26D8ED30>
# <__main__.Developer object at 0x000001EB271C1470>
# <__main__.Developer object at 0x000001EB2739E160>
# <__main__.Developer object at 0x000001EB27197940>
# <__main__.Developer object at 0x000001EB26CDB470>
# <__main__.Developer object at 0x000001EB26E56CF8>
# ...
# <__main__.Developer object at 0x000001EB272D0908>
# <__main__.Developer object at 0x000001EB27158CF8>
# <__main__.Developer object at 0x000001EB26F190F0>
# <__main__.Developer object at 0x000001EB2748CE10>
# <__main__.Developer object at 0x000001EB26EF2A20>
# <__main__.Developer object at 0x000001EB26BA4668>
# <__main__.Developer object at 0x000001EB26E78630>
# <__main__.Developer object at 0x000001EB27314240>
# <__main__.Developer object at 0x000001EB26CE9DD8>
# <__main__.Developer object at 0x000001EB26D616A0>
# <__main__.Developer object at 0x000001EB2721D668>
# <__main__.Developer object at 0x000001EB26F85668>
# <__main__.Developer object at 0x000001EB26E2E9E8>
# <__main__.Developer object at 0x000001EB270D7AC8>
# <__main__.Developer object at 0x000001EB2742E5C0>
# <__main__.Developer object at 0x000001EB274B7160>
# <__main__.Developer object at 0x000001EB26BF5A58>
# <__main__.Developer object at 0x000001EB272AD048>
# <__main__.Developer object at 0x000001EB27492B38>
# <__main__.Developer object at 0x000001EB27253F60>
# <__main__.Developer object at 0x000001EB27220748>
# <__main__.Developer object at 0x000001EB27097C50>
# <__main__.Developer object at 0x000001EB273F0B00>
# <__main__.Developer object at 0x000001EB26E0E208>
# <__main__.Developer object at 0x000001EB26CB9668>
# <__main__.Developer object at 0x000001EB26CA3EB8>
# <__main__.Developer object at 0x000001EB271D7400>
# <__main__.Developer object at 0x000001EB2732F358>
# <__main__.Developer object at 0x000001EB2736D668>
# <__main__.Developer object at 0x000001EB272ED828>
# <__main__.Developer object at 0x000001EB270FFDA0>
# <__main__.Developer object at 0x000001EB26DEEEB8>
# <__main__.Developer object at 0x000001EB26F005C0>
# <__main__.Developer object at 0x000001EB26D042B0>
# <__main__.Developer object at 0x000001EB2700D8D0>
# <__main__.Developer object at 0x000001EB27283D30>
# <__main__.Developer object at 0x000001EB27006278>
# <__main__.Developer object at 0x000001EB271F9208>
# <__main__.ProjectManager object at 0x000001EB27513860>
# <__main__.Developer object at 0x000001EB27231160>
# <__main__.Developer object at 0x000001EB26D69FD0>
# <__main__.Developer object at 0x000001EB27469828>
# <__main__.ProjectManager object at 0x000001EB274E9518>
# <__main__.Developer object at 0x000001EB26C7E390>
# <__main__.ProjectManager object at 0x000001EB274D8A58>
# <__main__.Developer object at 0x000001EB26D325F8>
# <__main__.Developer object at 0x000001EB26C3FCF8>
# <__main__.Developer object at 0x000001EB26C20AC8>
# <__main__.Developer object at 0x000001EB26EBD9B0>
# <__main__.Developer object at 0x000001EB26FA7278>
# <__main__.Developer object at 0x000001EB26E689B0>
# <__main__.Developer object at 0x000001EB274AB908>
# <__main__.Developer object at 0x000001EB26F8A588>
# <__main__.Developer object at 0x000001EB270AE630>
# <__main__.Developer object at 0x000001EB271E8EF0>
# <__main__.Developer object at 0x000001EB26D14588>
# <__main__.Developer object at 0x000001EB270960B8>
# <__main__.Developer object at 0x000001EB272153C8>
# <__main__.Developer object at 0x000001EB26FC1BA8>
# <__main__.Developer object at 0x000001EB271450B8>
# <__main__.Developer object at 0x000001EB273FA390>
# <__main__.Developer object at 0x000001EB26C15D68>
# <__main__.Developer object at 0x000001EB270CB278>
# <__main__.Developer object at 0x000001EB26FF8EB8>
# <__main__.Developer object at 0x000001EB274799B0>
# <__main__.Developer object at 0x000001EB26E37748>
# <__main__.Developer object at 0x000001EB26E59C88>
# <__main__.Developer object at 0x000001EB2738B438>
# <__main__.Developer object at 0x000001EB26D130B8>
# <__main__.Developer object at 0x000001EB26E72F98>
# <__main__.Developer object at 0x000001EB26B97D30>
# <__main__.ProjectManager object at 0x000001EB274D3048>
# <__main__.Developer object at 0x000001EB26E9AA20>
# <__main__.Developer object at 0x000001EB26F9B128>
# <__main__.Developer object at 0x000001EB26CB2DA0>
# <__main__.Developer object at 0x000001EB272ACD30>
# <__main__.Developer object at 0x000001EB26DAA748>
# <__main__.Developer object at 0x000001EB2714B860>
# <__main__.Developer object at 0x000001EB271A9EF0>
# <__main__.Developer object at 0x000001EB272BB390>
# <__main__.Developer object at 0x000001EB273BFDA0>
# <__main__.Developer object at 0x000001EB270502B0>
# <__main__.Developer object at 0x000001EB2722E0B8>
# <__main__.Developer object at 0x000001EB26F83E48>
# <__main__.Developer object at 0x000001EB26BBA4A8>
# <__main__.Developer object at 0x000001EB26F5C2E8>
# <__main__.Developer object at 0x000001EB26BD8438>
# <__main__.Developer object at 0x000001EB26D7AEB8>
# <__main__.Developer object at 0x000001EB273872B0>
# <__main__.Developer object at 0x000001EB26D75C18>
# <__main__.Developer object at 0x000001EB27309898>
# <__main__.Developer object at 0x000001EB2736D978>
# <__main__.Developer object at 0x000001EB2735C048>
# <__main__.Developer object at 0x000001EB271135C0>
# <__main__.Developer object at 0x000001EB26F60780>
# <__main__.Developer object at 0x000001EB27394DD8>
# <__main__.Developer object at 0x000001EB26F09978>
# <__main__.ProjectManager object at 0x000001EB274F4A20>
# <__main__.Developer object at 0x000001EB273B4710>
# <__main__.ProjectManager object at 0x000001EB274CE9B0>
# <__main__.Developer object at 0x000001EB27424A20>
# <__main__.Developer object at 0x000001EB274A4780>
# <__main__.Developer object at 0x000001EB27455080>
# <__main__.Developer object at 0x000001EB26CB2320>
# <__main__.Developer object at 0x000001EB26FB06A0>
# <__main__.Developer object at 0x000001EB270805C0>
# <__main__.Developer object at 0x000001EB2735FCC0>
# <__main__.Developer object at 0x000001EB273EF5F8>
# <__main__.Developer object at 0x000001EB26D108D0>
# <__main__.Developer object at 0x000001EB274992B0>
# <__main__.Developer object at 0x000001EB26C64BA8>
# <__main__.Developer object at 0x000001EB26DEDA58>
# <__main__.Developer object at 0x000001EB27490A90>
# <__main__.ProjectManager object at 0x000001EB274FA550>
# <__main__.ProjectManager object at 0x000001EB274CEC50>
# <__main__.Developer object at 0x000001EB26E36898>
# <__main__.Developer object at 0x000001EB27228F28>
# <__main__.Developer object at 0x000001EB26C889B0>
# <__main__.Developer object at 0x000001EB26DA52E8>
# <__main__.Developer object at 0x000001EB26ECE400>
# <__main__.Developer object at 0x000001EB27186B00>
# <__main__.Developer object at 0x000001EB27391470>
# <__main__.Developer object at 0x000001EB27352CC0>
# <__main__.Developer object at 0x000001EB27225240>
# <__main__.ProjectManager object at 0x000001EB274D8278>
# <__main__.ProjectManager object at 0x000001EB274EB7B8>
# <__main__.Developer object at 0x000001EB26C0B630>
# <__main__.Developer object at 0x000001EB26DFDC18>
# <__main__.Developer object at 0x000001EB27063B00>
# <__main__.Developer object at 0x000001EB26B9EEB8>
# <__main__.Developer object at 0x000001EB26CDBDA0>
# <__main__.ProjectManager object at 0x000001EB274FAB70>
# <__main__.Developer object at 0x000001EB27490668>
# <__main__.Developer object at 0x000001EB26C24550>
# <__main__.Developer object at 0x000001EB26F39F28>
# <__main__.Developer object at 0x000001EB2747EF60>
# <__main__.Developer object at 0x000001EB27366B38>
# <__main__.Developer object at 0x000001EB274BD550>
# <__main__.ProjectManager object at 0x000001EB274D6748>
# <__main__.Developer object at 0x000001EB26C7A208>
# <__main__.Developer object at 0x000001EB26D2B2E8>
# <__main__.Developer object at 0x000001EB26FF3710>
# <__main__.Developer object at 0x000001EB2717A630>
# <__main__.Developer object at 0x000001EB2735C7B8>
# <__main__.Developer object at 0x000001EB26FDBB38>
# <__main__.Developer object at 0x000001EB26D5A240>
# <__main__.Developer object at 0x000001EB2701B8D0>
# <__main__.Developer object at 0x000001EB272D1048>
# <__main__.Developer object at 0x000001EB26F376A0>
# <__main__.Developer object at 0x000001EB26D4B390>
# <__main__.Developer object at 0x000001EB26DA97F0>
# <__main__.Developer object at 0x000001EB272E32B0>
# <__main__.ProjectManager object at 0x000001EB27513BE0>
# <__main__.Developer object at 0x000001EB26D01FD0>
# <__main__.Developer object at 0x000001EB26F38D68>
# <__main__.Developer object at 0x000001EB270FA668>
# <__main__.Developer object at 0x000001EB274BD0B8>
# <__main__.Developer object at 0x000001EB2728FA90>
# <__main__.Developer object at 0x000001EB26BF53C8>
# <__main__.Developer object at 0x000001EB27043FD0>
# <__main__.Developer object at 0x000001EB270103C8>
# <__main__.Developer object at 0x000001EB272CA9E8>
# <__main__.Developer object at 0x000001EB271499B0>
# <__main__.Developer object at 0x000001EB26EE80F0>
# <__main__.Developer object at 0x000001EB26B331D0>
# <__main__.Developer object at 0x000001EB27216A20>
# <__main__.Developer object at 0x000001EB27092FD0>
# <__main__.Developer object at 0x000001EB274AEB70>
# <__main__.ProjectManager object at 0x000001EB274E3278>
# <__main__.Developer object at 0x000001EB26CA2518>
# <__main__.Developer object at 0x000001EB2716AB00>
# <__main__.Developer object at 0x000001EB26EC1DA0>
# <__main__.Developer object at 0x000001EB26D7DCF8>
# <__main__.Developer object at 0x000001EB2734A320>
# <__main__.Developer object at 0x000001EB27324128>
# <__main__.Developer object at 0x000001EB26E97160>
# <__main__.Developer object at 0x000001EB26F08358>
# <__main__.Developer object at 0x000001EB26BF8BE0>
# <__main__.Developer object at 0x000001EB26B9A2B0>
# <__main__.Developer object at 0x000001EB27490240>
# <__main__.Developer object at 0x000001EB273CB6D8>
# <__main__.Developer object at 0x000001EB27154080>
# <__main__.Developer object at 0x000001EB27161AC8>
# <__main__.Developer object at 0x000001EB273119E8>
# <__main__.Developer object at 0x000001EB270EDDA0>
# <__main__.Developer object at 0x000001EB27062A90>
# <__main__.Developer object at 0x000001EB270BEE48>
# <__main__.Developer object at 0x000001EB26EAC400>
# <__main__.Developer object at 0x000001EB26F49668>
# <__main__.Developer object at 0x000001EB26B985C0>
# <__main__.Developer object at 0x000001EB2725ECC0>
# <__main__.Developer object at 0x000001EB26CD0D30>
# <__main__.Developer object at 0x000001EB26D26EF0>
# <__main__.Developer object at 0x000001EB2717E080>
# <__main__.Developer object at 0x000001EB26BB02B0>
# <__main__.Developer object at 0x000001EB270D85F8>
# <__main__.Developer object at 0x000001EB272D7B38>
# <__main__.Developer object at 0x000001EB26C12C18>
# <__main__.Developer object at 0x000001EB26C4F4E0>
# <__main__.Developer object at 0x000001EB27489860>
# <__main__.Developer object at 0x000001EB270BBBE0>
# <__main__.ProjectManager object at 0x000001EB274C3E10>
# <__main__.Developer object at 0x000001EB26D3E7F0>
# <__main__.Developer object at 0x000001EB26C36160>
# <__main__.Developer object at 0x000001EB27467C50>
# <__main__.Developer object at 0x000001EB272CE278>
# <__main__.Developer object at 0x000001EB2700BC88>
# <__main__.ProjectManager object at 0x000001EB274CEB00>
# <__main__.Developer object at 0x000001EB26F82860>
# <__main__.Developer object at 0x000001EB26ED3400>
# <__main__.Developer object at 0x000001EB26D895F8>
# <__main__.Developer object at 0x000001EB271A90B8>
# <__main__.Developer object at 0x000001EB26E8A278>
# <__main__.Developer object at 0x000001EB2721B7B8>
# <__main__.Developer object at 0x000001EB271824A8>
# <__main__.Developer object at 0x000001EB26B90710>
# <__main__.Developer object at 0x000001EB26F49358>
# <__main__.Developer object at 0x000001EB26E6BC50>
# <__main__.Developer object at 0x000001EB26ED10F0>
# <__main__.ProjectManager object at 0x000001EB275031D0>
# <__main__.Developer object at 0x000001EB270AD8D0>
# <__main__.Developer object at 0x000001EB26C72710>
# <__main__.Developer object at 0x000001EB271D3240>
# <__main__.Developer object at 0x000001EB26FECDA0>
# <__main__.Developer object at 0x000001EB2726CE10>
# <__main__.Developer object at 0x000001EB2725C2E8>
# <__main__.Developer object at 0x000001EB27121A58>
# <__main__.Developer object at 0x000001EB27303F28>
# <__main__.Developer object at 0x000001EB27413748>
# <__main__.Developer object at 0x000001EB26E82A20>
# <__main__.ProjectManager object at 0x000001EB274CA7F0>
# <__main__.Developer object at 0x000001EB26F1C278>
# <__main__.Developer object at 0x000001EB27226EF0>
# <__main__.Developer object at 0x000001EB27332B38>
# <__main__.Developer object at 0x000001EB271051D0>
# <__main__.Developer object at 0x000001EB26C3EB70>
# <__main__.Developer object at 0x000001EB26BE0748>
# <__main__.Developer object at 0x000001EB272E62B0>
# <__main__.Developer object at 0x000001EB26CA1710>
# <__main__.Developer object at 0x000001EB27259390>
# <__main__.Developer object at 0x000001EB272839E8>
# <__main__.Developer object at 0x000001EB26C63668>
# <__main__.Developer object at 0x000001EB26F3CE10>
# <__main__.Developer object at 0x000001EB26DA6F60>
# <__main__.Developer object at 0x000001EB26FF56A0>
# <__main__.Developer object at 0x000001EB26E77FD0>
# <__main__.Developer object at 0x000001EB2703C438>
# <__main__.Developer object at 0x000001EB26E46DD8>
# <__main__.Developer object at 0x000001EB26B6F4A8>
# <__main__.Developer object at 0x000001EB26DFE898>
# <__main__.Developer object at 0x000001EB273CE780>
# <__main__.ProjectManager object at 0x000001EB275132B0>
# <__main__.ProjectManager object at 0x000001EB274CA550>
# <__main__.Developer object at 0x000001EB26B87588>
# <__main__.Developer object at 0x000001EB27163400>
# <__main__.Developer object at 0x000001EB26C9D470>
# <__main__.Developer object at 0x000001EB26E22E80>
# <__main__.Developer object at 0x000001EB270CF1D0>
# <__main__.Developer object at 0x000001EB26E79D68>
# <__main__.Developer object at 0x000001EB27005AC8>
# <__main__.Developer object at 0x000001EB27320278>
# <__main__.ProjectManager object at 0x000001EB274FAF60>
# <__main__.Developer object at 0x000001EB27481860>
# <__main__.Developer object at 0x000001EB26BE92B0>
# <__main__.Developer object at 0x000001EB270636D8>
# <__main__.Developer object at 0x000001EB26C24908>
# <__main__.Developer object at 0x000001EB271B76D8>
# <__main__.Developer object at 0x000001EB26F6DC50>
# <__main__.Developer object at 0x000001EB27360F98>
# <__main__.Developer object at 0x000001EB2710EA58>
# <__main__.Developer object at 0x000001EB271E3198>
# <__main__.Developer object at 0x000001EB27027A90>
# <__main__.Developer object at 0x000001EB26ECB4A8>
# <__main__.Developer object at 0x000001EB2723F908>
# <__main__.Developer object at 0x000001EB270757F0>
# <__main__.ProjectManager object at 0x000001EB274F6CC0>
# <__main__.Developer object at 0x000001EB273847F0>
# <__main__.Developer object at 0x000001EB26FD2E80>
# <__main__.Developer object at 0x000001EB272E02E8>
# <__main__.Developer object at 0x000001EB2742E0F0>
# <__main__.Developer object at 0x000001EB27078860>
# <__main__.Developer object at 0x000001EB273398D0>
# <__main__.Developer object at 0x000001EB2741B908>
# <__main__.Developer object at 0x000001EB272B3550>
# <__main__.Developer object at 0x000001EB26C1F198>
# <__main__.ProjectManager object at 0x000001EB274C69B0>
# <__main__.Developer object at 0x000001EB26C6C7F0>
# <__main__.Developer object at 0x000001EB26FC5828>
# <__main__.ProjectManager object at 0x000001EB274C78D0>
# <__main__.Developer object at 0x000001EB27234BE0>
# <__main__.Developer object at 0x000001EB2735DB00>
# <__main__.Developer object at 0x000001EB26C1E7F0>
# <__main__.Developer object at 0x000001EB2726FA90>
# <__main__.Developer object at 0x000001EB273DCD68>
# <__main__.Developer object at 0x000001EB26EC6C88>
# <__main__.Developer object at 0x000001EB26EA6D30>
# <__main__.ProjectManager object at 0x000001EB274DD908>
# <__main__.Developer object at 0x000001EB26FCD470>
# <__main__.Developer object at 0x000001EB26DE0A90>
# <__main__.Developer object at 0x000001EB26ED2B70>
# <__main__.Developer object at 0x000001EB272820B8>
# <__main__.Developer object at 0x000001EB26CA69B0>
# <__main__.Developer object at 0x000001EB273F7978>
# <__main__.Developer object at 0x000001EB27208FD0>
# <__main__.Developer object at 0x000001EB274A5C88>
# <__main__.Developer object at 0x000001EB273AC208>
# <__main__.Developer object at 0x000001EB26EBD4E0>
# <__main__.Developer object at 0x000001EB27359E48>
# <__main__.Developer object at 0x000001EB272CD828>
# <__main__.Developer object at 0x000001EB26BB72E8>
# <__main__.Developer object at 0x000001EB27433D30>
# <__main__.Developer object at 0x000001EB273EE9E8>
# <__main__.Developer object at 0x000001EB26E3F390>
# <__main__.Developer object at 0x000001EB274609E8>
# <__main__.Developer object at 0x000001EB26CFC0B8>
# <__main__.Developer object at 0x000001EB26DD6048>
# <__main__.Developer object at 0x000001EB27494F28>

# %%
score = 0

filename = 'out_'+l+'.txt'
with open(filename, 'a') as out:
    to_print = ''
    for dev in developers:
        if dev.placed == 0:
            to_print += 'X\n'
        else:
            to_print += str(dev.coord[1])+' '+str(dev.coord[0])+'\n'
    for man in managers:
        if man.placed == 0:
            to_print += 'X\n'
        else:
            to_print += str(man.coord[1])+' '+str(man.coord[0])+'\n'
    to_print = to_print[:-1]
    print(to_print, file = out)
