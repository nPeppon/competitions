# %%
import numpy as np
from operator import attrgetter
import cmath

# %%
filenames = ['data/a.txt',
             'data/b.txt',
             'data/c.txt',
             'data/d.txt',
             'data/e.txt',
             'data/f.txt']

# %%
l = 'd'

int_to_letter = {0 : 'a', 1 : 'b', 2 : 'c', 3 : 'd', 4 : 'f', 5 : 'g'}
letter_to_int = {'a':0, 'b':1, 'c':2, 'd':3, 'e':4, 'f':5}

f = open(filenames[letter_to_int[l]])

# %%
#Define objects involved

class Contributors():
    def __init__(self,):
class Street():
    
    def __init__(self, index, intersection_start, intersection_end, street_name, time_needed_to_ride):
        self.index = index
        self.intersection_start = intersection_start
        self.intersection_end = intersection_end
        self.street_name = street_name
        self.time_needed_to_ride = time_needed_to_ride
        self.optimal_out_green_time = []
        self.loop = -1
        self.window = -1
        self.offset = -1
        
    def addGreenTimeCarScore(self, green_time, car_score):
        self.optimal_out_green_time.append((green_time, car_score))
        
    def computeLoop(self, total_time, max_percentage = 3):
        time_set = list(set([x[0] for x in self.optimal_out_green_time]))
        time_set.sort(key=lambda x: x, reverse=False)
        if (len(time_set) == 0):
            pass
        elif (len(time_set) == 1):
            self.loop = time_set[0]
            self.offset = 1
            self.window = 1
        else:
            self.offset = time_set[0]
            temp_sum = 0
            for i in range(1, len(time_set)):
                temp_sum += (time_set[i] - time_set[i - 1])
            loop = temp_sum / (len(time_set) - 1)
            self.loop = int(loop)
            resto = loop % self.loop
            resto = abs(0.5 - resto)

            if (resto < 0.1):
                self.window = int(self.loop / 2)
            elif (resto < 0.3):
                self.window = int(self.loop / 3)
            else:
                self.window = 1
            
            if self.window > total_time/100*max_percentage:
                self.window = int(total_time/100*max_percentage)
            
    def sortTimeCarScoreList():
        self.optimal_out_green_timer_list.sort(key=lambda x: x[0], reverse=False)

        
class Car():
    
    def __init__(self, index, num_streets_to_cross):
        self.index = index
        self.num_streets_to_cross = num_streets_to_cross
        self.streets_list = []
        self.total_minimum_time = 0
        self.score = 0
        
    def addStreetToList(self, street):
        self.streets_list.append(street)
        if (len(self.streets_list) != 1):
            self.total_minimum_time += street.time_needed_to_ride
        
    def computeScore(self, total_time):
        self.score = (total_time - self.total_minimum_time)/total_time
        
class Intersection():
    
    def __init__(self, index):
        self.index = index
        self.streets = []
        self.time_map = {}
        self.loop = -1
        self.window = -1
        self.offset = -1
        self.out = {}
        self.solution_street_time = []
        
    def resetSolution(self):
        self.solution_street_time = []
        
    def addStreet(self, street):
        self.streets.append(street)
                
    def addTimeWithCarScoreAndStreet(self, time, car_score, street):
        if time in self.time_map:
            current_tuple = self.time_map.get(time)
            if current_tuple[0] < car_score:
                self.time_map[time] = (car_score, street)
        else:
            self.time_map[time] = (car_score, street)
            
    def addSolution(self, street, time_duration, pos = None):
        if pos is None:
            pos = len(self.solution_street_time)
        self.solution_street_time.insert(pos, [street, time_duration])
            
    def printSolution(self):
        out_string = str(len(self.solution_street_time)) + '\n'
        for val in self.solution_street_time:
            out_string += val[0].street_name + ' ' + str(val[1]) + '\n'
        return out_string
        
#     def addOptimalGreenTimeForCarScoreStreet(self, green_time, car_score, street):
#         self
        
class Triple():
    
    def __init__(self, green_time, car_score):
        self.green_time = green_time
        self.car_score = car_score
        
def getMostRecurringStreet(time_street_map):
    track={}

    for key,value in time_street_map.items():
        if value not in track:
            track[value] = 0
        else:
            track[value] += 1

    return max(track,key=track.get)

def removeElemFromMapByValue(map_to_update, value):
    #in this case the value reference only the second val of the tuple
    map_to_update = {key:val for key, val in map_to_update.items() if val != value}
    return map_to_update
    
def findMofLine(K, total_exptected_area_sum, q = 0):
    total_k_sum = 0
    total_k_sum = K * int(K/2) + int(K/2)
    if K % 2 != 0:
        total_k_sum += 1
    m = (total_exptected_area_sum -K*q)/total_k_sum
    return m

def getPosSolutionToQuadEq(c, a=1, b=1):
    # calculate the discriminant
    d = (b**2) - (4*a*c)

    # find two solutions
    sol1 = (-b-cmath.sqrt(d))/(2*a)
    sol2 = (-b+cmath.sqrt(d))/(2*a)
    
    return int(sol2.real)

# %%
#Parse input file
print('Reading first line')
line = f.readline()
D = int(line.split(' ')[0])
I = int(line.split(' ')[1])
S = int(line.split(' ')[2])
V = int(line.split(' ')[3])
F = int(line.split(' ')[4])

duration = D
num_intersection = I
num_streets = S
num_cars = V
bonus = F

print('Duration ' + str(duration))
# Out:
# Reading first line
# Duration 8071

# %%
# Looping through streets
street_list = []
streets_map = {}
intersection_map = {}
for s in range(S):
    line = f.readline()
    lineSplit = line.split(' ')
    intersection_start = int(lineSplit[0])
    intersection_end = int(lineSplit[1])
    name = lineSplit[2]
    time_needed = int(lineSplit[3])
    street = Street(s, intersection_start, intersection_end, name, time_needed)
    street_list.append(street)
    streets_map[name] = street
    
    if (intersection_end in intersection_map):
        intersection_map.get(intersection_end).addStreet(street)
    else:
        intersection_out_object = Intersection(intersection_end)
        intersection_out_object.addStreet(street)
        intersection_map[intersection_end] = intersection_out_object

# %%
# print(intersection_map)

# %%
# Looping through cars
car_list = []

for v in range(V):
    line = f.readline()
    # Split first the newline to avoid it
    lineSplit = line.split('\n')[0].split(' ')
    num_streets = int(lineSplit[0])
    car = Car(v, num_streets)
    for i in range(num_streets):
        car.addStreetToList(streets_map.get(lineSplit[i + 1]))
    car.computeScore(duration)
    car_list.append(car)

# %%
#Sort car list based on their score

car_list.sort(key=lambda x: x.score, reverse=True)
# newlist = sorted(ut, key=lambda x: x.count, reverse=True)

# %%
# print([x.score for x in car_list])

# %%
for car in car_list:
    if (car.score >= 0):
        time = 0
        for i, street in enumerate(car.streets_list):
            if i != 0:
                time += street.time_needed_to_ride
            street.addGreenTimeCarScore(time, car.score)
            intersection_map.get(street.intersection_end).addTimeWithCarScoreAndStreet(time, car.score, street)

# %%
num_of_actual_inter = num_intersection
to_print = ''

num_loop = 20
loop_duration = int(duration / num_loop)
print('Loop duration ' + str(loop_duration))
# intersections_with_solution = []
for idx,inter in intersection_map.items():
    if (len(inter.time_map) > 0):
        inter.resetSolution()
        # In this solution we are not considering car score so we exclude them
        time_street_map = {key:val[1] for key, val in inter.time_map.items()}
#             print('Time_map len: ' +str(len(time_street_map)))
        streets = {val:0 for key, val in time_street_map.items()}
        print('Inter id: ' + str(idx))
        print('Streets num ' + str(len(streets)))
        if loop_duration < 0:
            loop_duration = len(streets)
            print('Loop duration ' + str(loop_duration))
#             print(time_street_map)
        stillSomeStreetsLeft = True
        num_of_streets_to_put = getPosSolutionToQuadEq(-loop_duration*2)

        strategy_new = False
        def_window = 1
        remaing_time = 0
        num_of_streets_to_put_with_more_time = 0
        if (loop_duration / len(streets)) > 1:
            strategy_new = True
            remaing_time = loop_duration % len(streets)
            num_of_streets_to_put_with_more_time = getPosSolutionToQuadEq(-remaing_time*2)
            print('num_of_streets_to_put_with_more_time ' +str(num_of_streets_to_put_with_more_time))
            print('remaing_time ' +str(remaing_time))
            
#             print('Time street map len: ' + str(len(time_street_map)))
#             print('Line eq: ' + str(m) + ' * x')
        current_offset = 0
        while (stillSomeStreetsLeft and current_offset < loop_duration):
            most_recurring_street = getMostRecurringStreet(time_street_map)
            time_street_map = removeElemFromMapByValue(time_street_map, most_recurring_street)
            streets.pop(most_recurring_street)
            most_recurring_street.computeLoop(duration)

            window = 0
#             print('\tStreet ' + most_recurring_street.street_name)
            if strategy_new:
                window = def_window
                if num_of_streets_to_put_with_more_time > 0:
                    window += num_of_streets_to_put_with_more_time
                    num_of_streets_to_put_with_more_time -= 1
#                 print('\tWindow: ' + str(window))
            else:
                window = num_of_streets_to_put
                num_of_streets_to_put -= 1
            inter.addSolution(most_recurring_street, window)
            current_offset += window

            if len(streets) == 0 or (not strategy_new and num_of_streets_to_put == 0):
                stillSomeStreetsLeft = False

        if current_offset != loop_duration and len(inter.solution_street_time) > 0:
            print('Fixing final offset')
            inter.solution_street_time[0][1] += (loop_duration - current_offset)
            current_offset = duration

        if len(inter.solution_street_time) > 0:
            to_print += str(idx) + '\n'
            to_print += inter.printSolution()
        else:
            num_of_actual_inter -= 1   
    else:
        num_of_actual_inter -= 1
#     break
to_print = str(num_of_actual_inter) + '\n' + to_print


to_print = to_print[:-1]
# Out:
# Loop duration 403
# Inter id: 6
# Streets num 262
# num_of_streets_to_put_with_more_time 16
# remaing_time 141
# Fixing final offset
# Inter id: 0
# Streets num 18
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 8
# Streets num 264
# num_of_streets_to_put_with_more_time 16
# remaing_time 139
# Fixing final offset
# Inter id: 45
# Streets num 117
# num_of_streets_to_put_with_more_time 9
# remaing_time 52
# Fixing final offset
# Inter id: 58
# Streets num 63
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 90
# Streets num 50
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 228
# Streets num 54
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 419
# Streets num 24
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 659
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 673
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 768
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 969
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1182
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 1567
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 3048
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3080
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3830
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5478
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5849
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6018
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7343
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7776
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 1
# Streets num 119
# num_of_streets_to_put_with_more_time 9
# remaing_time 46
# Fixing final offset
# Inter id: 7
# Streets num 186
# num_of_streets_to_put_with_more_time 7
# remaing_time 31
# Fixing final offset
# Inter id: 9
# Streets num 166
# num_of_streets_to_put_with_more_time 11
# remaing_time 71
# Fixing final offset
# Inter id: 10
# Streets num 145
# num_of_streets_to_put_with_more_time 14
# remaing_time 113
# Fixing final offset
# Inter id: 12
# Streets num 238
# num_of_streets_to_put_with_more_time 17
# remaing_time 165
# Fixing final offset
# Inter id: 15
# Streets num 106
# num_of_streets_to_put_with_more_time 12
# remaing_time 85
# Fixing final offset
# Inter id: 27
# Streets num 131
# num_of_streets_to_put_with_more_time 4
# remaing_time 10
# Fixing final offset
# Inter id: 28
# Streets num 88
# num_of_streets_to_put_with_more_time 9
# remaing_time 51
# Fixing final offset
# Inter id: 31
# Streets num 33
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 38
# Streets num 92
# num_of_streets_to_put_with_more_time 7
# remaing_time 35
# Fixing final offset
# Inter id: 51
# Streets num 109
# num_of_streets_to_put_with_more_time 11
# remaing_time 76
# Fixing final offset
# Inter id: 56
# Streets num 81
# num_of_streets_to_put_with_more_time 12
# remaing_time 79
# Fixing final offset
# Inter id: 78
# Streets num 54
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 85
# Streets num 70
# num_of_streets_to_put_with_more_time 9
# remaing_time 53
# Fixing final offset
# Inter id: 118
# Streets num 36
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 122
# Streets num 28
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 123
# Streets num 47
# num_of_streets_to_put_with_more_time 6
# remaing_time 27
# Fixing final offset
# Inter id: 151
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 160
# Streets num 34
# num_of_streets_to_put_with_more_time 7
# remaing_time 29
# Fixing final offset
# Inter id: 200
# Streets num 51
# num_of_streets_to_put_with_more_time 9
# remaing_time 46
# Fixing final offset
# Inter id: 230
# Streets num 39
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 233
# Streets num 45
# num_of_streets_to_put_with_more_time 8
# remaing_time 43
# Fixing final offset
# Inter id: 243
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 255
# Streets num 33
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 257
# Streets num 26
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 258
# Streets num 24
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 263
# Streets num 40
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 329
# Streets num 39
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 371
# Streets num 27
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 374
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 378
# Streets num 35
# num_of_streets_to_put_with_more_time 5
# remaing_time 18
# Fixing final offset
# Inter id: 385
# Streets num 31
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 406
# Streets num 21
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 464
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 478
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 493
# Streets num 18
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 501
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 515
# Streets num 34
# num_of_streets_to_put_with_more_time 7
# remaing_time 29
# Fixing final offset
# Inter id: 517
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 541
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 558
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 608
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 626
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 657
# Streets num 25
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 745
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 749
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 836
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 844
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 895
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 923
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 937
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 954
# Streets num 32
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 958
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 963
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 980
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 1038
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1048
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1107
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1226
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1294
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1332
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1334
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1335
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1346
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1362
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 1400
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1406
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 1590
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 1620
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1622
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1640
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 1670
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 1679
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1681
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 1688
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1706
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1749
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 1755
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1788
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 1805
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 1983
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 2065
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 2097
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2240
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 2418
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2462
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2541
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2732
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2861
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2887
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2924
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2956
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2989
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3241
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3311
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3388
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3491
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3516
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3842
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3862
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3873
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3895
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3975
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4127
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4157
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 4238
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4248
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4267
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4306
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4631
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4656
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4680
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4688
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4709
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4811
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4844
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4904
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5061
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5152
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5166
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5173
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5224
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5226
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5253
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5264
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5314
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5323
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5340
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5363
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5383
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5385
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5386
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5500
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5506
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5584
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5856
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5887
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5939
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5948
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5963
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6097
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6361
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6422
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6426
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6859
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6860
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7161
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7199
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7264
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7407
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7593
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7622
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7832
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7935
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 2
# Streets num 198
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 11
# Streets num 229
# num_of_streets_to_put_with_more_time 18
# remaing_time 174
# Fixing final offset
# Inter id: 17
# Streets num 177
# num_of_streets_to_put_with_more_time 9
# remaing_time 49
# Fixing final offset
# Inter id: 18
# Streets num 119
# num_of_streets_to_put_with_more_time 9
# remaing_time 46
# Fixing final offset
# Inter id: 20
# Streets num 119
# num_of_streets_to_put_with_more_time 9
# remaing_time 46
# Fixing final offset
# Inter id: 22
# Streets num 87
# num_of_streets_to_put_with_more_time 10
# remaing_time 55
# Fixing final offset
# Inter id: 24
# Streets num 69
# num_of_streets_to_put_with_more_time 10
# remaing_time 58
# Fixing final offset
# Inter id: 32
# Streets num 134
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 43
# Streets num 50
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 50
# Streets num 119
# num_of_streets_to_put_with_more_time 9
# remaing_time 46
# Fixing final offset
# Inter id: 54
# Streets num 120
# num_of_streets_to_put_with_more_time 8
# remaing_time 43
# Fixing final offset
# Inter id: 67
# Streets num 55
# num_of_streets_to_put_with_more_time 5
# remaing_time 18
# Fixing final offset
# Inter id: 81
# Streets num 84
# num_of_streets_to_put_with_more_time 11
# remaing_time 67
# Fixing final offset
# Inter id: 83
# Streets num 56
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 86
# Streets num 42
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 88
# Streets num 67
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 97
# Streets num 33
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 102
# Streets num 43
# num_of_streets_to_put_with_more_time 5
# remaing_time 16
# Fixing final offset
# Inter id: 154
# Streets num 65
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 166
# Streets num 37
# num_of_streets_to_put_with_more_time 7
# remaing_time 33
# Fixing final offset
# Inter id: 170
# Streets num 34
# num_of_streets_to_put_with_more_time 7
# remaing_time 29
# Fixing final offset
# Inter id: 187
# Streets num 42
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 198
# Streets num 56
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 206
# Streets num 27
# num_of_streets_to_put_with_more_time 6
# remaing_time 25
# Fixing final offset
# Inter id: 225
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 237
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 264
# Streets num 70
# num_of_streets_to_put_with_more_time 9
# remaing_time 53
# Fixing final offset
# Inter id: 265
# Streets num 26
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 299
# Streets num 38
# num_of_streets_to_put_with_more_time 6
# remaing_time 23
# Fixing final offset
# Inter id: 317
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 341
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 359
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 365
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 369
# Streets num 28
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 416
# Streets num 34
# num_of_streets_to_put_with_more_time 7
# remaing_time 29
# Fixing final offset
# Inter id: 420
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 422
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 444
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 451
# Streets num 36
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 456
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 498
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 508
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 510
# Streets num 29
# num_of_streets_to_put_with_more_time 6
# remaing_time 26
# Fixing final offset
# Inter id: 519
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 522
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 525
# Streets num 37
# num_of_streets_to_put_with_more_time 7
# remaing_time 33
# Fixing final offset
# Inter id: 554
# Streets num 23
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 590
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 606
# Streets num 21
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 611
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 612
# Streets num 26
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 620
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 656
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 658
# Streets num 28
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 661
# Streets num 18
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 663
# Streets num 25
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 687
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 692
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 732
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 733
# Streets num 29
# num_of_streets_to_put_with_more_time 6
# remaing_time 26
# Fixing final offset
# Inter id: 739
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 773
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 778
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 780
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 798
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 813
# Streets num 25
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 829
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 877
# Streets num 28
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 882
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 973
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 986
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 987
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 997
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 1027
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1086
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1141
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1213
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1223
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1246
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 1265
# Streets num 24
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 1325
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 1342
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1355
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 1383
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1434
# Streets num 31
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1451
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 1452
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1464
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1484
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1486
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1499
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1589
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1643
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1649
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1673
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1678
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1683
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1723
# Streets num 15
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 1734
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1739
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 1750
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1777
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1808
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 1955
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1964
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1987
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2025
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2036
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2109
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2128
# Streets num 17
# num_of_streets_to_put_with_more_time 4
# remaing_time 12
# Fixing final offset
# Inter id: 2161
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2181
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 2206
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2228
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2234
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2248
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2285
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2290
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2330
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2331
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2379
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2384
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 2389
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2435
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2443
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2495
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 2536
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2537
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 2547
# Streets num 18
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2557
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2563
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2627
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2630
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2643
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2677
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2846
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2918
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2939
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3070
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3156
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 3201
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3307
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3362
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3392
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3410
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 3423
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3483
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 3660
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3707
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3854
# Streets num 3
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3875
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3909
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4002
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4035
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4067
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4090
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 4140
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 4243
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4295
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4322
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4430
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4433
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4467
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4546
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4557
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4559
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4562
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4614
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4668
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4683
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4732
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4747
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4785
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 4835
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4882
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4892
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4983
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5115
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5128
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5150
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5228
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5349
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5407
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5463
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5473
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5505
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5513
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5601
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5648
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5714
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5759
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5782
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5857
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5882
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5891
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5896
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5905
# Streets num 3
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5982
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5986
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6106
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6262
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6363
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6423
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6434
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6461
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6631
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6723
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6724
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6754
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6760
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6761
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6797
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6809
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6916
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6970
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6975
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7062
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7083
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7160
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7179
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7260
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7336
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7532
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7589
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7611
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7630
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7717
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7794
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7813
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7877
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7905
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3
# Streets num 76
# num_of_streets_to_put_with_more_time 6
# remaing_time 23
# Fixing final offset
# Inter id: 14
# Streets num 175
# num_of_streets_to_put_with_more_time 9
# remaing_time 53
# Fixing final offset
# Inter id: 48
# Streets num 97
# num_of_streets_to_put_with_more_time 5
# remaing_time 15
# Fixing final offset
# Inter id: 95
# Streets num 58
# num_of_streets_to_put_with_more_time 10
# remaing_time 55
# Fixing final offset
# Inter id: 137
# Streets num 50
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 150
# Streets num 22
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 172
# Streets num 32
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 177
# Streets num 53
# num_of_streets_to_put_with_more_time 7
# remaing_time 32
# Fixing final offset
# Inter id: 214
# Streets num 39
# num_of_streets_to_put_with_more_time 4
# remaing_time 13
# Fixing final offset
# Inter id: 244
# Streets num 31
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 246
# Streets num 20
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 391
# Streets num 24
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 407
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 414
# Streets num 16
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 443
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 471
# Streets num 29
# num_of_streets_to_put_with_more_time 6
# remaing_time 26
# Fixing final offset
# Inter id: 585
# Streets num 21
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 667
# Streets num 29
# num_of_streets_to_put_with_more_time 6
# remaing_time 26
# Fixing final offset
# Inter id: 756
# Streets num 19
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 763
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 765
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 794
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 879
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 904
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 972
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1142
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1212
# Streets num 24
# num_of_streets_to_put_with_more_time 5
# remaing_time 19
# Fixing final offset
# Inter id: 1225
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 1521
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 1668
# Streets num 13
# num_of_streets_to_put_with_more_time 0
# remaing_time 0
# Fixing final offset
# Inter id: 1748
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 1942
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2230
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2284
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2291
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 2368
# Streets num 11
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2370
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2457
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2558
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2659
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 2775
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2800
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2853
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 2973
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3014
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 3150
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3235
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3382
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3400
# Streets num 12
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3460
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3486
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3522
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3565
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 3984
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4010
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4081
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 4177
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# ...
# Fixing final offset
# Inter id: 7893
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4025
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7999
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6807
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5214
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7507
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3399
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5692
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5592
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4027
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5321
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5879
# Streets num 3
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4937
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6425
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4438
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 4330
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4462
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6382
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7706
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5577
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 7446
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6904
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4156
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5631
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7849
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6140
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5410
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3936
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7177
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5496
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6348
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6832
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5763
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6207
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3171
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7437
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5490
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4287
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7103
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5365
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7673
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6915
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7491
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 5952
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5181
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 2850
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7924
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6641
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5392
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7669
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6848
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6901
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5186
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4742
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7940
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5746
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4849
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7087
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6299
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7474
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5122
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5562
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7024
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7095
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4929
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6941
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5179
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 3812
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7293
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 3237
# Streets num 10
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6201
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7477
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7916
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6142
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7852
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4528
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4745
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5222
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7015
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6991
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5560
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7790
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7546
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7668
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5716
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6935
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7989
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7487
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4927
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6114
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7500
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7868
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5927
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7333
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6267
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6037
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4517
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6617
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3903
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7923
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7439
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7569
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7526
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7687
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6403
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6607
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7291
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4982
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 7735
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6646
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5771
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6109
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7284
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 4697
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 7527
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6850
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7943
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4001
# Streets num 14
# num_of_streets_to_put_with_more_time 4
# remaing_time 11
# Fixing final offset
# Inter id: 5960
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7646
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6468
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3347
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5167
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5297
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6505
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5909
# Streets num 3
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5162
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6386
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7903
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7048
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5134
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7434
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 6050
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7386
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 3950
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5983
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6522
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 5446
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5474
# Streets num 9
# num_of_streets_to_put_with_more_time 3
# remaing_time 7
# Fixing final offset
# Inter id: 5430
# Streets num 8
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5660
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4739
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 6459
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4839
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7807
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 4553
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7041
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6317
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7433
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 5720
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6124
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 7958
# Streets num 6
# num_of_streets_to_put_with_more_time 1
# remaing_time 1
# Fixing final offset
# Inter id: 6213
# Streets num 7
# num_of_streets_to_put_with_more_time 2
# remaing_time 4
# Fixing final offset
# Inter id: 7368
# Streets num 5
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset
# Inter id: 7262
# Streets num 4
# num_of_streets_to_put_with_more_time 2
# remaing_time 3
# Fixing final offset

# %%
print('Ended')
# Out:
# Ended

# %%
# print(to_print)

# %%
filename = 'out_'+l+'.txt'
with open(filename, 'a') as out:
    print(to_print, file = out)

# %%
# len(intersection_map.get(6).streets)
